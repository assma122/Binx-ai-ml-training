# %% [markdown]
# <div style="
# padding:32px 34px;
# border-radius:26px;
# background:
# linear-gradient(135deg,#11131A 0%,#171A23 55%,#1F2230 100%);
# border:1px solid rgba(255,255,255,.08);
# box-shadow:0 18px 50px rgba(0,0,0,.22);
# font-family:Arial,sans-serif;
# color:white;
# ">
#
# <div style="
# font-size:10px;
# font-weight:800;
# letter-spacing:2.4px;
# color:#A78BFA;
# margin-bottom:12px;
# ">
# WEEK 09 • DAY 02
# </div>
#
# <div style="
# font-size:32px;
# font-weight:800;
# line-height:1.2;
# margin-bottom:12px;
# ">
# Serving the Model
# <span style="color:#A78BFA;">with FastAPI</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.8;
# color:#C7CBD6;
# max-width:850px;
# ">
# Transforming the trained IMDb sentiment model into a reliable REST API
# that validates user reviews, applies the same preprocessing pipeline,
# and returns structured predictions.
# </div>
#
# <div style="
# margin-top:26px;
# padding:14px 16px;
# border-radius:16px;
# background:rgba(255,255,255,.05);
# border:1px solid rgba(255,255,255,.08);
# font-size:13px;
# color:#E5E7EB;
# ">
# <span style="color:#A78BFA;font-weight:700;">FLOW</span>
# &nbsp;&nbsp;
# Review → Validation → Preprocessing → TF-IDF → Model → JSON
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:26px 28px;
# border-radius:22px;
# background:linear-gradient(135deg,#FFF8FC 0%,#F9F5FF 50%,#F2F8FF 100%);
# border:1px solid #E9E1F1;
# box-shadow:0 10px 28px rgba(126,87,194,0.08);
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:11px;
# font-weight:700;
# letter-spacing:1.8px;
# color:#A46AD6;
# margin-bottom:8px;
# ">
# INTRODUCTION
# </div>
#
#
#
# <div style="
# font-size:14px;
# line-height:1.85;
# color:#5F5B6B;
# max-width:900px;
# ">
# In Day 1, the trained
# <span style="color:#A15CC2;font-weight:700;">Logistic Regression model</span>
# and the fitted
# <span style="color:#5D7BD8;font-weight:700;">TF-IDF vectorizer</span>
# were serialized and prepared for deployment.
# </div>
#
# <div style="
# margin:16px 0;
# padding:11px 14px;
# border-radius:14px;
# background:rgba(255,255,255,.72);
# border:1px solid #E8E1F2;
# text-align:center;
# font-size:12px;
# font-weight:700;
# color:#625C70;
# letter-spacing:.2px;
# ">
# <span style="color:#A15CC2;">Saved Model</span>
# &nbsp; → &nbsp;
# <span style="color:#5D7BD8;">FastAPI</span>
# &nbsp; → &nbsp;
# <span style="color:#5FA88A;">Prediction Service</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.85;
# color:#5F5B6B;
# max-width:900px;
# ">
# Today, we move one step closer to a real application by building a
# <span style="color:#E07A9C;font-weight:700;">FastAPI REST service</span>
# that can receive a movie review, validate the input, apply the same
# <span style="color:#5FA88A;font-weight:700;">preprocessing pipeline</span>,
# and return a
# <span style="color:#D58B3F;font-weight:700;">sentiment prediction</span>
# as a structured JSON response.
# </div>
#
# <div style="
# margin-top:18px;
# padding:13px 15px;
# border-radius:14px;
# background:rgba(255,255,255,.72);
# border:1px solid #EAE3F3;
# font-size:13px;
# line-height:1.7;
# color:#4E4A59;
# ">
# <span style="color:#8B67D3;font-weight:800;">DAY 2 FOCUS</span>
# &nbsp;—&nbsp;
# Turn the saved IMDb sentiment model into a service that can be called by a
# <span style="color:#D66F96;font-weight:700;">website</span>,
# <span style="color:#6285D7;font-weight:700;">mobile app</span>,
# or another
# <span style="color:#5DA08A;font-weight:700;">backend system</span>.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:24px 26px;
# border-radius:20px;
# background:linear-gradient(135deg,#FFF8FC 0%,#F8F5FF 50%,#F3F8FF 100%);
# border:1px solid #E9E2F2;
# box-shadow:0 9px 26px rgba(109,86,150,.08);
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:13px;
# font-weight:800;
# letter-spacing:1.8px;
# color:#9270D2;
# margin-bottom:7px;
# ">
# DAY 2 · TABLE OF CONTENTS
# </div>
#
# <div style="
# font-size:25px;
# font-weight:800;
# color:#292633;
# margin-bottom:16px;
# ">
# Today's Roadmap
# </div>
#
# <div style="
# display:grid;
# grid-template-columns:1fr 1fr;
# gap:13px;
# ">
#
# <div style="
# padding:15px 16px;
# border-radius:15px;
# background:linear-gradient(135deg,#FFFFFF,#FCF8FF);
# border:1px solid #EEE6F4;
# ">
# <div style="
# font-size:12px;
# font-weight:800;
# color:#A15CC2;
# margin-bottom:6px;
# ">
# 2.1 · FASTAPI
# </div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#413C49;
# margin-bottom:4px;
# ">
# What FastAPI Does
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#625D69;
# ">
# Turn the trained model into a
# <span style="color:#A15CC2;font-weight:800;">REST API service</span>
# that other applications can call.
# </div>
# </div>
#
#
# <div style="
# padding:15px 16px;
# border-radius:15px;
# background:linear-gradient(135deg,#FFFFFF,#F7FAFF);
# border:1px solid #E5ECF8;
# ">
# <div style="
# font-size:12px;
# font-weight:800;
# color:#5D7BD8;
# margin-bottom:6px;
# ">
# 2.2 · PREDICTION ENDPOINT
# </div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#413C49;
# margin-bottom:4px;
# ">
# POST /predict
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#625D69;
# ">
# Receive a movie review and return a
# <span style="color:#5D7BD8;font-weight:800;">sentiment prediction</span>
# as JSON.
# </div>
# </div>
#
#
# <div style="
# padding:15px 16px;
# border-radius:15px;
# background:linear-gradient(135deg,#FFFFFF,#F7FFF9);
# border:1px solid #E2F0E7;
# ">
# <div style="
# font-size:12px;
# font-weight:800;
# color:#5FA88A;
# margin-bottom:6px;
# ">
# 2.3 · PYDANTIC
# </div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#413C49;
# margin-bottom:4px;
# ">
# Input Validation
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#625D69;
# ">
# Validate incoming data using
# <span style="color:#5FA88A;font-weight:800;">Pydantic schemas</span>
# before prediction.
# </div>
# </div>
#
#
# <div style="
# padding:15px 16px;
# border-radius:15px;
# background:linear-gradient(135deg,#FFFFFF,#FFF9F2);
# border:1px solid #F1E7D8;
# ">
# <div style="
# font-size:12px;
# font-weight:800;
# color:#D58B3F;
# margin-bottom:6px;
# ">
# 2.4 · API TESTING
# </div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#413C49;
# margin-bottom:4px;
# ">
# Uvicorn & /docs
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#625D69;
# ">
# Run the API locally and test it through FastAPI's
# <span style="color:#D58B3F;font-weight:800;">interactive documentation</span>.
# </div>
# </div>
#
#
# <div style="
# padding:15px 16px;
# border-radius:15px;
# background:linear-gradient(135deg,#FFFFFF,#FFF7FB);
# border:1px solid #F1E4EB;
# ">
# <div style="
# font-size:12px;
# font-weight:800;
# color:#D66F96;
# margin-bottom:6px;
# ">
# 2.5 · HANDS-ON LAB
# </div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#413C49;
# margin-bottom:4px;
# ">
# Prediction Testing
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#625D69;
# ">
# Test
# <span style="color:#D66F96;font-weight:800;">valid</span>
# and
# <span style="color:#B56C84;font-weight:800;">invalid requests</span>
# and verify clean error handling.
# </div>
# </div>
#
#
# <div style="
# padding:15px 16px;
# border-radius:15px;
# background:linear-gradient(135deg,#FFFFFF,#F9F7FF);
# border:1px solid #EAE5F4;
# ">
# <div style="
# font-size:12px;
# font-weight:800;
# color:#8B67D3;
# margin-bottom:6px;
# ">
# 2.6 · SUMMARY
# </div>
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#413C49;
# margin-bottom:4px;
# ">
# Day 2 Takeaway
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#625D69;
# ">
# Confirm the complete flow from
# <span style="color:#8B67D3;font-weight:800;">request</span>
# to
# <span style="color:#5D7BD8;font-weight:800;">JSON response</span>.
# </div>
# </div>
#
# </div>
#
# <div style="
# margin-top:15px;
# padding:12px 14px;
# border-radius:13px;
# background:linear-gradient(90deg,#F8F3FF,#FFF7FA,#F4FAFF);
# border:1px solid #ECE5F3;
# font-size:13.5px;
# font-weight:700;
# text-align:center;
# color:#55505E;
# ">
#
# <span style="color:#A15CC2;">LOAD</span>
# &nbsp;→&nbsp;
# <span style="color:#5D7BD8;">SERVE</span>
# &nbsp;→&nbsp;
# <span style="color:#5FA88A;">VALIDATE</span>
# &nbsp;→&nbsp;
# <span style="color:#D58B3F;">TEST</span>
# &nbsp;→&nbsp;
# <span style="color:#D66F96;">PREDICT</span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:18px 20px;
# border-radius:16px;
# background:linear-gradient(135deg,#F5F3FF,#FFF7FB,#F8FBFF);
# border:1px solid #E7DDF5;
# box-shadow:0 6px 18px rgba(124,58,237,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:18px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#8B5CF6;
# margin-bottom:6px;
# ">
# DAY 2 · VISUAL OVERVIEW
# </div>
#
# <div style="
# font-size:21px;
# font-weight:850;
# color:#1E293B;
# margin-bottom:7px;
# ">
# IMDb Sentiment API Workflow
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# A high-level view of how a movie review moves through the
# <span style="color:#2563EB;font-weight:800;">FastAPI service</span>
# until the final
# <span style="color:#7C3AED;font-weight:800;">sentiment prediction</span>
# is returned.
# </div>
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="
# padding:13px 15px;
# border-radius:13px;
# background:#F8FAFC;
# border-left:4px solid #7C3AED;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 20px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# color:#7C3AED;
# letter-spacing:1.2px;
# margin-bottom:4px;
# ">
# WORKFLOW INSIGHT
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# The client sends a
# <span style="color:#DB2777;font-weight:800;">movie review</span>
# to the
# <span style="color:#2563EB;font-weight:800;">/predict endpoint</span>.
# The review is then preprocessed, transformed using the saved
# <span style="color:#2563EB;font-weight:800;">TF-IDF vectorizer</span>,
# and passed to the
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>.
# Finally, FastAPI returns the prediction as a structured
# <span style="color:#059669;font-weight:800;">JSON response</span>.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     padding:20px 22px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#FFF9FC,#F7F3FF,#EEF6FF,#FFFFFF);
#     border:1px solid #E8D9FF;
#     box-shadow:0 8px 22px rgba(168,85,247,.07);
#     margin:18px 0;
# ">
#
# <div style="
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:1.5px;
#     color:#9333EA;
#     margin-bottom:6px;
# ">
# 2.1
# </div>
#
# <div style="
#     font-size:23px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:9px;
# ">
# What FastAPI Does
# </div>
#
# <div style="
#     font-size:14px;
#     line-height:1.65;
#     color:#475569;
# ">
# <span style="color:#7C3AED;font-weight:700;">FastAPI</span> is a modern Python framework for building
# <span style="color:#2563EB;font-weight:700;">REST APIs</span> — web endpoints that allow other applications to communicate with a trained model.
#
# Instead of running the IMDb sentiment classifier manually inside a notebook, we expose it through an
# <span style="color:#DB2777;font-weight:700;">API endpoint</span>.
# A website, mobile application, or another backend can send a movie review and receive the predicted sentiment in return.
# </div>
#
# </div>
#
# <div style="
#     background:#EFF6FF;
#     border-left:4px solid #3B82F6;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:16px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#1D4ED8;
#     margin-bottom:5px;
# ">
# How This Changes Our Workflow
# </div>
#
# <div style="
#     font-size:13.5px;
#     line-height:1.6;
#     color:#475569;
# ">
# The model is no longer limited to the notebook.
# FastAPI turns it into a <b>service</b> that other systems can call whenever they need a prediction.
# </div>
#
# </div>
#
# <div style="
#     background:linear-gradient(135deg,#F5F3FF,#FDF2F8,#FFFFFF);
#     border:1px solid #DDD6FE;
#     border-radius:15px;
#     padding:15px 17px;
#     margin:18px 0;
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:800;
#     color:#6D28D9;
#     margin-bottom:7px;
# ">
# IMDb Deployment Flow
# </div>
#
# <div style="
#     font-size:13.5px;
#     line-height:1.65;
#     color:#475569;
# ">
# <span style="color:#DB2777;font-weight:700;">Movie Review</span>
# &nbsp;→&nbsp;
# <span style="color:#2563EB;font-weight:700;">FastAPI</span>
# &nbsp;→&nbsp;
# <span style="color:#059669;font-weight:700;">Preprocessing</span>
# &nbsp;→&nbsp;
# <span style="color:#7C3AED;font-weight:700;">TF-IDF</span>
# &nbsp;→&nbsp;
# <span style="color:#D97706;font-weight:700;">Logistic Regression</span>
# &nbsp;→&nbsp;
# <span style="color:#DB2777;font-weight:700;">Sentiment Prediction</span>
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:20px 22px;
# border-radius:18px;
# background:linear-gradient(135deg,#FFF9FC,#F7F3FF,#EEF6FF,#FFFFFF);
# border:1px solid #E8D9FF;
# box-shadow:0 8px 22px rgba(168,85,247,.07);
# margin:18px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:12px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#9333EA;
# margin-bottom:6px;
# ">
# 2.2 · LESSON CONTENT
# </div>
#
# <div style="
# font-size:24px;
# font-weight:800;
# color:#1E293B;
# margin-bottom:10px;
# ">
# A Minimal Prediction Endpoint
# </div>
#
# <div style="
# font-size:14.5px;
# line-height:1.72;
# color:#475569;
# ">
# A FastAPI application defines
# <span style="color:#9333EA;font-weight:800;">routes</span>
# that represent URLs other applications can call.
#
# For model prediction, we create a
# <span style="color:#DB2777;font-weight:800;">POST /predict</span>
# endpoint because the client needs to send a movie review to the API.
#
# The endpoint receives the review, applies the same
# <span style="color:#059669;font-weight:800;">text preprocessing</span>
# used during training, transforms the cleaned text using the saved
# <span style="color:#2563EB;font-weight:800;">TF-IDF vectorizer</span>,
# and passes the resulting features to the
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>.
# </div>
#
# </div>
#
# <div style="
# background:#EFF6FF;
# border-left:4px solid #3B82F6;
# border-radius:0 12px 12px 0;
# padding:13px 16px;
# margin:16px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#1D4ED8;
# margin-bottom:5px;
# ">
# Why Do We Use POST?
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#475569;
# ">
# A <span style="color:#2563EB;font-weight:800;">POST request</span>
# allows the client to send the movie review inside the request body.
# The API processes that review and returns the prediction as a
# <span style="color:#9333EA;font-weight:800;">JSON response</span>.
# </div>
#
# </div>
#
# <div style="
# background:linear-gradient(135deg,#F5F3FF,#FDF2F8,#FFFFFF);
# border:1px solid #DDD6FE;
# border-radius:15px;
# padding:15px 17px;
# margin:18px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:16px;
# font-weight:800;
# color:#6D28D9;
# margin-bottom:7px;
# ">
# Prediction Flow
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# <span style="color:#DB2777;font-weight:800;">POST /predict</span>
# &nbsp;→&nbsp;
# <span style="color:#059669;font-weight:800;">Preprocess Review</span>
# &nbsp;→&nbsp;
# <span style="color:#2563EB;font-weight:800;">TF-IDF Transform</span>
# &nbsp;→&nbsp;
# <span style="color:#7C3AED;font-weight:800;">Model Prediction</span>
# &nbsp;→&nbsp;
# <span style="color:#D97706;font-weight:800;">JSON Response</span>
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:20px 22px;
# border-radius:18px;
# background:linear-gradient(135deg,#FFF9FC,#F7F3FF,#EEF6FF,#FFFFFF);
# border:1px solid #E8D9FF;
# box-shadow:0 8px 22px rgba(168,85,247,.07);
# margin:18px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:12px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#9333EA;
# margin-bottom:6px;
# ">
# 2.3 · LESSON CONTENT
# </div>
#
# <div style="
# font-size:24px;
# font-weight:800;
# color:#1E293B;
# margin-bottom:10px;
# ">
# Pydantic Input Validation
# </div>
#
# <div style="
# font-size:14.5px;
# line-height:1.72;
# color:#475569;
# ">
# Before an incoming review reaches the model, the API should first check that the request contains the
# <span style="color:#DB2777;font-weight:800;">expected data</span>
# in the correct format.
#
# <span style="color:#7C3AED;font-weight:800;">Pydantic</span>
# provides this validation automatically by defining the structure and data types expected by the API.
#
# If a required field is missing, or the submitted value does not match the expected type,
# <span style="color:#2563EB;font-weight:800;">FastAPI rejects the request</span>
# with a clear validation error instead of allowing bad input to reach the model.
# </div>
#
# </div>
#
# <div style="
# background:#ECFDF5;
# border-left:4px solid #10B981;
# border-radius:0 12px 12px 0;
# padding:13px 16px;
# margin:16px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#047857;
# margin-bottom:5px;
# ">
# Why Validation Matters
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#475569;
# ">
# A prediction service should never assume that incoming data is correct.
#
# Validation acts as a
# <span style="color:#059669;font-weight:800;">safety layer</span>
# between the client and the machine-learning pipeline, preventing malformed requests from causing unexpected failures.
# </div>
#
# </div>
#
# <div style="
# background:linear-gradient(135deg,#F5F3FF,#FDF2F8,#FFFFFF);
# border:1px solid #DDD6FE;
# border-radius:15px;
# padding:15px 17px;
# margin:18px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:16px;
# font-weight:800;
# color:#6D28D9;
# margin-bottom:7px;
# ">
# Validation Flow
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# <span style="color:#DB2777;font-weight:800;">Incoming Request</span>
# &nbsp;→&nbsp;
# <span style="color:#059669;font-weight:800;">Pydantic Validation</span>
# &nbsp;→&nbsp;
# <span style="color:#2563EB;font-weight:800;">Valid Input</span>
# &nbsp;→&nbsp;
# <span style="color:#7C3AED;font-weight:800;">Prediction Pipeline</span>
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:20px 22px;
# border-radius:18px;
# background:linear-gradient(135deg,#FFF9FC,#F7F3FF,#EEF6FF,#FFFFFF);
# border:1px solid #E8D9FF;
# box-shadow:0 8px 22px rgba(168,85,247,.07);
# margin:18px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:12px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#9333EA;
# margin-bottom:6px;
# ">
# 2.4 · LESSON CONTENT
# </div>
#
# <div style="
# font-size:24px;
# font-weight:800;
# color:#1E293B;
# margin-bottom:10px;
# ">
# Testing the API
# </div>
#
# <div style="
# font-size:14.5px;
# line-height:1.72;
# color:#475569;
# ">
# After defining the prediction endpoint, the next step is to confirm that the complete service works correctly from
# <span style="color:#DB2777;font-weight:800;">request</span>
# to
# <span style="color:#7C3AED;font-weight:800;">prediction</span>.
#
# FastAPI automatically generates interactive documentation at the
# <span style="color:#2563EB;font-weight:800;">/docs</span>
# URL, allowing us to test API endpoints directly from the browser without building a separate client application.
#
# The API is typically run locally using
# <span style="color:#059669;font-weight:800;">Uvicorn</span>,
# which starts the FastAPI application as a web server.
# </div>
#
# </div>
#
# <div style="
# background:#FFF7ED;
# border-left:4px solid #F59E0B;
# border-radius:0 12px 12px 0;
# padding:13px 16px;
# margin:16px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:15px;
# font-weight:800;
# color:#B45309;
# margin-bottom:5px;
# ">
# What Are We Verifying?
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.65;
# color:#475569;
# ">
# Testing confirms that the entire inference chain works correctly:
# the request reaches the endpoint, the input passes
# <span style="color:#059669;font-weight:800;">validation</span>,
# the saved preprocessing is applied, the model produces a prediction, and the API returns a valid
# <span style="color:#D97706;font-weight:800;">JSON response</span>.
# </div>
#
# </div>
#
# <div style="
# background:linear-gradient(135deg,#EEF6FF,#F5F3FF,#FDF2F8);
# border:1px solid #DDE7FA;
# border-radius:15px;
# padding:15px 17px;
# margin:18px 0;
# font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
# font-size:16px;
# font-weight:800;
# color:#2563EB;
# margin-bottom:7px;
# ">
# Local Testing Flow
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# <span style="color:#059669;font-weight:800;">Run Uvicorn</span>
# &nbsp;→&nbsp;
# <span style="color:#2563EB;font-weight:800;">Open /docs</span>
# &nbsp;→&nbsp;
# <span style="color:#DB2777;font-weight:800;">Send Review</span>
# &nbsp;→&nbsp;
# <span style="color:#7C3AED;font-weight:800;">Call /predict</span>
# &nbsp;→&nbsp;
# <span style="color:#D97706;font-weight:800;">Inspect Response</span>
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:22px 24px;
# border-radius:18px;
# background:linear-gradient(135deg,#7C3AED,#A855F7,#EC4899);
# box-shadow:0 10px 28px rgba(124,58,237,.18);
# font-family:'Trebuchet MS',sans-serif;
# margin:20px 0 24px 0;
# text-align:center;
# ">
#
# <div style="
# font-size:25px;
# font-weight:900;
# color:#FFFFFF;
# letter-spacing:.5px;
# ">
# ✓ THEORY COMPLETE
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:24px 26px;
# border-radius:20px;
# background:linear-gradient(135deg,#FFF1F7 0%,#F7F0FF 45%,#EEF5FF 100%);
# border:1px solid #E9D8F5;
# box-shadow:0 10px 28px rgba(132,84,185,.10);
# font-family:'Trebuchet MS',sans-serif;
# margin:24px 0 18px 0;
# ">
#
# <div style="
# font-size:12px;
# font-weight:800;
# letter-spacing:1.8px;
# color:#A855F7;
# margin-bottom:7px;
# ">
# HANDS-ON LAB
# </div>
#
# <div style="
# font-size:25px;
# font-weight:900;
# color:#1E293B;
# margin-bottom:8px;
# ">
# Building the Prediction API
# </div>
#
# <div style="
# font-size:14.5px;
# line-height:1.75;
# color:#475569;
# margin-bottom:16px;
# ">
# We will now turn the Day 2 theory into a complete
# <span style="color:#7C3AED;font-weight:800;">FastAPI prediction service</span>
# for the IMDb sentiment model.
# </div>
#
# <table style="
# width:100%;
# border-collapse:separate;
# border-spacing:0;
# overflow:hidden;
# border-radius:14px;
# background:#FFFFFF;
# border:1px solid #E9E2F1;
# font-size:14px;
# color:#475569;
# ">
#
# <tr style="background:linear-gradient(90deg,#F5EEFF,#FFF3F8,#EEF5FF);">
# <th style="padding:12px 14px;text-align:left;color:#7C3AED;font-size:13px;">STEP</th>
# <th style="padding:12px 14px;text-align:left;color:#7C3AED;font-size:13px;">TASK</th>
# <th style="padding:12px 14px;text-align:left;color:#7C3AED;font-size:13px;">PURPOSE</th>
# </tr>
#
# <tr>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#A855F7;">01</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#1E293B;">Load Saved Artifacts</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;">
# Load the <span style="color:#7C3AED;font-weight:800;">model</span> and
# <span style="color:#2563EB;font-weight:800;">TF-IDF vectorizer</span> from Day 1.
# </td>
# </tr>
#
# <tr style="background:#FCFAFF;">
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#2563EB;">02</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#1E293B;">Define Input Schema</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;">
# Use <span style="color:#059669;font-weight:800;">Pydantic</span> to validate incoming movie reviews.
# </td>
# </tr>
#
# <tr>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#059669;">03</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#1E293B;">Build /predict Endpoint</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;">
# Apply preprocessing, TF-IDF transformation, and return the
# <span style="color:#DB2777;font-weight:800;">sentiment prediction</span>.
# </td>
# </tr>
#
# <tr style="background:#FCFAFF;">
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#D97706;">04</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#1E293B;">Run & Test the API</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;">
# Start the service with <span style="color:#D97706;font-weight:800;">Uvicorn</span> and test it through
# <span style="color:#2563EB;font-weight:800;">/docs</span>.
# </td>
# </tr>
#
# <tr>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#DB2777;">05</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;font-weight:800;color:#1E293B;">Test Invalid Input</td>
# <td style="padding:12px 14px;border-top:1px solid #EEE8F3;">
# Confirm that invalid requests are rejected cleanly by
# <span style="color:#DB2777;font-weight:800;">Pydantic validation</span>.
# </td>
# </tr>
#
# </table>
#
# </div>

# %% [markdown]
# <div style="
#     background:#EFF6FF;
#     border-left:4px solid #3B82F6;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:18px 0 12px 0;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.3px;
#     color:#2563EB;
#     margin-bottom:5px;
# ">
# STEP 1
# </div>
#
# <div style="
#     font-size:20px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:6px;
# ">
# Load the Saved Model & Preprocessing
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# The first step is to restore the deployment artifacts created on Day 1.
#
# We load the saved
# <span style="color:#7C3AED;font-weight:700;">Logistic Regression model</span>
# and fitted
# <span style="color:#2563EB;font-weight:700;">TF-IDF vectorizer</span>
# so the FastAPI service can reuse the exact trained workflow
# <span style="color:#059669;font-weight:700;">without retraining</span>.
# </div>
#
# </div>

# %%
from pathlib import Path
import joblib

from fastapi import FastAPI
from pydantic import BaseModel

MODEL_PATH = Path("../Day1/model.joblib")
VECTORIZER_PATH = Path("../Day1/vectorizer.joblib")

model = joblib.load(MODEL_PATH)
vectorizer = joblib.load(VECTORIZER_PATH)

app = FastAPI(
    title="IMDb Sentiment API",
    description="Predicts whether a movie review is Positive or Negative.",
    version="1.0.0"
)

print("Model:", type(model).__name__)
print("Vectorizer:", type(vectorizer).__name__)
print("FastAPI app created successfully.")
# Out:
# Model: LogisticRegression
# Vectorizer: TfidfVectorizer
# FastAPI app created successfully.

# %% [markdown]
# <div style="
# background:#ECFDF5;
# border-left:4px solid #10B981;
# border-radius:0 12px 12px 0;
# padding:12px 15px;
# margin:12px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.2px;
# color:#059669;
# margin-bottom:4px;
# ">
# ✓ STEP 1 RESULT
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.6;
# color:#475569;
# ">
# The saved <span style="color:#7C3AED;font-weight:700;">Logistic Regression model</span>
# and <span style="color:#2563EB;font-weight:700;">TF-IDF vectorizer</span>
# were loaded successfully, and the
# <span style="color:#059669;font-weight:700;">FastAPI application</span>
# is ready for the next deployment step.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#F5F3FF;
#     border-left:4px solid #8B5CF6;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:18px 0 12px 0;
#     font-family:'Trebuchet MS',sans-serif;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.3px;
#     color:#7C3AED;
#     margin-bottom:5px;
# ">
# STEP 2
# </div>
#
# <div style="
#     font-size:20px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:6px;
# ">
# Define the Pydantic Input Schema
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# The API needs a clear structure for the data it expects to receive.
#
# Using
# <span style="color:#7C3AED;font-weight:700;">Pydantic</span>,
# we define a request schema containing one required field:
# <span style="color:#DB2777;font-weight:700;">review</span>.
#
# This ensures that incoming requests are validated before they reach the prediction pipeline.
# </div>
#
# </div>

# %%
from pydantic import BaseModel, Field

class ReviewInput(BaseModel):
    review: str = Field(
        ...,
        min_length=3,
        max_length=5000
    )

# %% [markdown]
# <div style="
# padding:12px 15px;
# border-radius:13px;
# background:#ECFDF5;
# border-left:4px solid #10B981;
# font-family:'Trebuchet MS',sans-serif;
# margin:12px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.2px;
# color:#059669;
# margin-bottom:4px;
# ">
# ✓ STEP 2 RESULT
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# The
# <span style="color:#7C3AED;font-weight:800;">ReviewInput</span>
# schema now validates that every request contains a
# <span style="color:#DB2777;font-weight:800;">review</span>
# field with a valid string length between
# <span style="color:#2563EB;font-weight:800;">3 and 5000 characters</span>.
#
# This prevents empty, extremely short, or excessively long reviews from reaching the prediction pipeline.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:18px 20px;
# border-radius:16px;
# background:linear-gradient(135deg,#F5F3FF,#FFF7FB,#F8FBFF);
# border:1px solid #E7DDF5;
# box-shadow:0 6px 18px rgba(124,58,237,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#8B5CF6;
# margin-bottom:6px;
# ">
# STEP 3 · PREPROCESSING
# </div>
#
# <div style="
# font-size:19px;
# font-weight:800;
# color:#1E293B;
# margin-bottom:6px;
# ">
# Reuse the <span style="color:#059669;">Exact Training Preprocessing</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# Before calling the prediction endpoint, we reuse the
# <span style="color:#059669;font-weight:800;">same text preprocessing pipeline</span>
# from Day 1 so the saved
# <span style="color:#2563EB;font-weight:800;">TF-IDF vectorizer</span>
# receives input in the same format used during training.
# </div>
#
# </div>

# %%
import re
import html
import nltk

from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

resources = [
    "punkt",
    "punkt_tab",
    "stopwords",
    "wordnet",
    "omw-1.4",
    "averaged_perceptron_tagger_eng"
]

for resource in resources:
    nltk.download(resource, quiet=True)

negation_words = {"not", "no", "nor"}
stop_words = set(stopwords.words("english")) - negation_words
lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(tag):
    if tag.startswith("J"):
        return wordnet.ADJ
    elif tag.startswith("V"):
        return wordnet.VERB
    elif tag.startswith("N"):
        return wordnet.NOUN
    elif tag.startswith("R"):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def preprocess_review(text):
    text = html.unescape(str(text))
    text = re.sub(r"<[^>]+>", " ", text)
    text = re.sub(r"n['’]t\b", " not", text)
    text = text.lower()
    text = re.sub(r"\d+", " ", text)
    text = re.sub(r"[^\w\s']", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    tokens = word_tokenize(text)

    tokens = [
        token for token in tokens
        if token not in stop_words and len(token) > 1
    ]

    tagged_tokens = pos_tag(tokens)

    lemmas = [
        lemmatizer.lemmatize(word, get_wordnet_pos(tag))
        for word, tag in tagged_tokens
    ]

    lemmas = [
        word for word in lemmas
        if not word.startswith("'")
    ]

    return " ".join(lemmas)

# %% [markdown]
# <div style="
# padding:18px 20px;
# border-radius:16px;
# background:linear-gradient(135deg,#F5F3FF,#FFF7FB,#F8FBFF);
# border:1px solid #E7DDF5;
# box-shadow:0 6px 18px rgba(124,58,237,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#8B5CF6;
# margin-bottom:6px;
# ">
# HANDS-ON LAB · STEP 3
# </div>
#
# <div style="
# font-size:19px;
# font-weight:800;
# color:#1E293B;
# margin-bottom:6px;
# ">
# Build the <span style="color:#DB2777;">/predict</span> Endpoint
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# The endpoint receives a validated review, applies the
# <span style="color:#059669;font-weight:800;">preprocessing function</span>,
# transforms the text using the saved
# <span style="color:#2563EB;font-weight:800;">TF-IDF vectorizer</span>,
# runs the
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>,
# and returns the final sentiment prediction as
# <span style="color:#DB2777;font-weight:800;">JSON</span>.
# </div>
#
# </div>

# %%
@app.get("/health")
def health_check():
    return {
        "status": "healthy",
        "model": type(model).__name__
    }

# %% [markdown]
# <div style="
# padding:12px 15px;
# border-radius:13px;
# background:#EFF6FF;
# border-left:4px solid #3B82F6;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# color:#2563EB;
# letter-spacing:1.2px;
# margin-bottom:4px;
# ">
# HEALTH CHECK
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# The
# <span style="color:#2563EB;font-weight:800;">GET /health</span>
# endpoint provides a simple way to confirm that the FastAPI service is running and that the
# <span style="color:#7C3AED;font-weight:800;">trained model</span>
# has been loaded successfully.
# </div>
#
# </div>

# %%
@app.post("/predict")
def predict_sentiment(data: ReviewInput):
    cleaned_review = preprocess_review(data.review)

    review_vector = vectorizer.transform([cleaned_review])

    prediction = model.predict(review_vector)[0]
    probabilities = model.predict_proba(review_vector)[0]

    sentiment = "Positive" if prediction == 1 else "Negative"
    confidence = float(probabilities.max())

    return {
        "review": data.review,
        "prediction": sentiment,
        "confidence": round(confidence, 4)
    }

# %% [markdown]
# <div style="
# padding:14px 16px;
# border-radius:14px;
# background:linear-gradient(135deg,#ECFDF5,#F0FDF4,#FFFFFF);
# border:1px solid #CDEDD8;
# box-shadow:0 5px 16px rgba(16,185,129,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:12px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.4px;
# color:#059669;
# margin-bottom:5px;
# ">
# ✓ STEP 3 RESULT
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# The
# <span style="color:#DB2777;font-weight:800;">/predict endpoint</span>
# now accepts a validated review, applies the
# <span style="color:#059669;font-weight:800;">same preprocessing pipeline</span>,
# transforms it using the saved
# <span style="color:#2563EB;font-weight:800;">TF-IDF vectorizer</span>,
# and uses the
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>
# to return both the predicted sentiment and a
# <span style="color:#D97706;font-weight:800;">confidence score</span>
# as a structured JSON response.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:18px 20px;
# border-radius:16px;
# background:linear-gradient(135deg,#F5F3FF,#FFF7FB,#F8FBFF);
# border:1px solid #E7DDF5;
# box-shadow:0 6px 18px rgba(124,58,237,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#8B5CF6;
# margin-bottom:6px;
# ">
# HANDS-ON LAB · STEP 4
# </div>
#
# <div style="
# font-size:19px;
# font-weight:800;
# color:#1E293B;
# margin-bottom:6px;
# ">
# Run & Test the API through <span style="color:#2563EB;">/docs</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# Now we run the
# <span style="color:#D97706;font-weight:800;">FastAPI server</span>
# locally using
# <span style="color:#7C3AED;font-weight:800;">Uvicorn</span>,
# then open the automatic
# <span style="color:#2563EB;font-weight:800;">Swagger documentation</span>
# to test the
# <span style="color:#DB2777;font-weight:800;">/predict endpoint</span>
# with several movie reviews.
# </div>
#
# </div>

# %%
# %%writefile main.py

from pathlib import Path
import re
import html
import joblib
import nltk

from fastapi import FastAPI
from pydantic import BaseModel, Field

from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag


# --------------------------------------------------
# Load Day 1 artifacts
# --------------------------------------------------

BASE_DIR = Path(__file__).resolve().parent
DAY1_DIR = BASE_DIR.parent / "Day1"

MODEL_PATH = DAY1_DIR / "model.joblib"
VECTORIZER_PATH = DAY1_DIR / "vectorizer.joblib"

model = joblib.load(MODEL_PATH)
vectorizer = joblib.load(VECTORIZER_PATH)


# --------------------------------------------------
# Reuse the exact training preprocessing
# --------------------------------------------------

resources = [
    "punkt",
    "punkt_tab",
    "stopwords",
    "wordnet",
    "omw-1.4",
    "averaged_perceptron_tagger_eng"
]

for resource in resources:
    nltk.download(resource, quiet=True)

negation_words = {"not", "no", "nor"}

stop_words = set(stopwords.words("english")) - negation_words

lemmatizer = WordNetLemmatizer()


def get_wordnet_pos(tag):

    if tag.startswith("J"):
        return wordnet.ADJ

    elif tag.startswith("V"):
        return wordnet.VERB

    elif tag.startswith("N"):
        return wordnet.NOUN

    elif tag.startswith("R"):
        return wordnet.ADV

    return wordnet.NOUN


def preprocess_review(text):

    text = html.unescape(str(text))

    text = re.sub(
        r"<[^>]+>",
        " ",
        text
    )

    text = re.sub(
        r"n['’]t\b",
        " not",
        text
    )

    text = text.lower()

    text = re.sub(
        r"\d+",
        " ",
        text
    )

    text = re.sub(
        r"[^\w\s']",
        " ",
        text
    )

    text = re.sub(
        r"\s+",
        " ",
        text
    ).strip()

    tokens = word_tokenize(text)

    tokens = [
        token
        for token in tokens
        if token not in stop_words
        and len(token) > 1
    ]

    tagged_tokens = pos_tag(tokens)

    lemmas = [
        lemmatizer.lemmatize(
            word,
            get_wordnet_pos(tag)
        )
        for word, tag in tagged_tokens
    ]

    lemmas = [
        word
        for word in lemmas
        if not word.startswith("'")
    ]

    return " ".join(lemmas)


# --------------------------------------------------
# FastAPI application
# --------------------------------------------------

app = FastAPI(
    title="IMDb Sentiment API",
    description="Predicts whether a movie review is Positive or Negative.",
    version="1.0.0"
)


# --------------------------------------------------
# Pydantic input schema
# --------------------------------------------------

class ReviewInput(BaseModel):

    review: str = Field(
        ...,
        min_length=3,
        max_length=5000
    )


# --------------------------------------------------
# Health endpoint
# --------------------------------------------------

@app.get("/health")
def health_check():

    return {
        "status": "healthy",
        "model": type(model).__name__
    }


# --------------------------------------------------
# Prediction endpoint
# --------------------------------------------------

@app.post("/predict")
def predict_sentiment(data: ReviewInput):

    cleaned_review = preprocess_review(
        data.review
    )

    review_vector = vectorizer.transform(
        [cleaned_review]
    )

    prediction = model.predict(
        review_vector
    )[0]

    probabilities = model.predict_proba(
        review_vector
    )[0]

    sentiment = (
        "Positive"
        if prediction == 1
        else "Negative"
    )

    confidence = float(
        probabilities.max()
    )

    return {
        "review": data.review,
        "prediction": sentiment,
        "confidence": round(
            confidence,
            4
        )
    }
# Out:
# Overwriting main.py

# %% [markdown]
# ### Run the API Locally
#
# ```bash
# python -m uvicorn main:app --port 8020

# %% [markdown]
# http://127.0.0.1:8020/docs

# %% [markdown]
# <div style="
# padding:14px 16px;
# border-radius:14px;
# background:linear-gradient(135deg,#F5F3FF,#FFF7FB,#F8FBFF);
# border:1px solid #E7DDF5;
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.3px;
# color:#8B5CF6;
# margin-bottom:5px;
# ">
# STEP 4 · API DOCUMENTATION
# </div>
#
# <div style="
# font-size:18px;
# font-weight:800;
# color:#1E293B;
# ">
# Open the FastAPI <span style="color:#2563EB;">Swagger /docs</span> Interface
# </div>
#
# </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div style="
# padding:13px 15px;
# border-radius:13px;
# background:#F8FAFC;
# border-left:4px solid #2563EB;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# color:#2563EB;
# letter-spacing:1.2px;
# margin-bottom:4px;
# ">
# OBSERVATION
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# The FastAPI application is running successfully, and the
# <span style="color:#2563EB;font-weight:800;">Swagger /docs interface</span>
# now displays both the
# <span style="color:#059669;font-weight:800;">GET /health</span>
# endpoint for service monitoring and the
# <span style="color:#DB2777;font-weight:800;">POST /predict</span>
# endpoint for sentiment prediction.
# </div>
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="
# padding:13px 15px;
# border-radius:13px;
# background:#ECFDF5;
# border-left:4px solid #10B981;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# color:#059669;
# letter-spacing:1.2px;
# margin-bottom:4px;
# ">
# HEALTH CHECK RESULT
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# The
# <span style="color:#2563EB;font-weight:800;">GET /health</span>
# endpoint returned a
# <span style="color:#059669;font-weight:800;">200 Successful Response</span>,
# confirming that the FastAPI service is running correctly and the
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>
# has been loaded successfully.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:14px 16px;
# border-radius:14px;
# background:linear-gradient(135deg,#F5F3FF,#FFF7FB,#F8FBFF);
# border:1px solid #E7DDF5;
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.3px;
# color:#8B5CF6;
# margin-bottom:5px;
# ">
# STEP 4 · POSITIVE TEST CASE
# </div>
#
# <div style="
# font-size:18px;
# font-weight:800;
# color:#1E293B;
# ">
# Test the <span style="color:#DB2777;">/predict</span> Endpoint with a Positive Review
# </div>
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="
# padding:13px 15px;
# border-radius:13px;
# background:#F0FDF4;
# border-left:4px solid #10B981;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# color:#059669;
# letter-spacing:1.2px;
# margin-bottom:4px;
# ">
# POSITIVE TEST RESULT
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# The <span style="color:#DB2777;font-weight:800;">POST /predict</span>
# endpoint returned a
# <span style="color:#059669;font-weight:800;">200 Successful Response</span>
# and classified the review as
# <span style="color:#7C3AED;font-weight:800;">Positive</span>
# with a confidence score of
# <span style="color:#D97706;font-weight:800;">0.9813</span>,
# showing a strong prediction for positive sentiment.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:14px 16px;
# border-radius:14px;
# background:linear-gradient(135deg,#F5F3FF,#FFF7FB,#F8FBFF);
# border:1px solid #E7DDF5;
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.3px;
# color:#8B5CF6;
# margin-bottom:5px;
# ">
# STEP 4 · NEGATIVE TEST CASE
# </div>
#
# <div style="
# font-size:18px;
# font-weight:800;
# color:#1E293B;
# ">
# Test the <span style="color:#DB2777;">/predict</span> Endpoint with a Negative Review
# </div>
#
# </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div style="
# padding:13px 15px;
# border-radius:13px;
# background:#FFF7F7;
# border-left:4px solid #DB2777;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# color:#DB2777;
# letter-spacing:1.2px;
# margin-bottom:4px;
# ">
# NEGATIVE TEST RESULT
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# The <span style="color:#DB2777;font-weight:800;">POST /predict</span>
# endpoint returned a
# <span style="color:#059669;font-weight:800;">200 Successful Response</span>
# and classified the review as
# <span style="color:#DB2777;font-weight:800;">Negative</span>
# with a confidence score of
# <span style="color:#D97706;font-weight:800;">0.9975</span>,
# showing a very strong prediction for negative sentiment.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:18px 20px;
# border-radius:16px;
# background:linear-gradient(135deg,#F5F3FF,#FFF7FB,#F8FBFF);
# border:1px solid #E7DDF5;
# box-shadow:0 6px 18px rgba(124,58,237,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#8B5CF6;
# margin-bottom:6px;
# ">
# HANDS-ON LAB · STEP 5
# </div>
#
# <div style="
# font-size:19px;
# font-weight:800;
# color:#1E293B;
# margin-bottom:6px;
# ">
# Validate <span style="color:#DB2777;">Invalid Input</span> with Pydantic
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# The final step verifies that
# <span style="color:#7C3AED;font-weight:800;">Pydantic validation</span>
# rejects requests that do not match the expected input schema.
#
# A valid request must contain a
# <span style="color:#2563EB;font-weight:800;">review</span>
# field with a string value. Invalid requests should return a clear
# <span style="color:#DB2777;font-weight:800;">422 Validation Error</span>
# instead of reaching the prediction model.
# </div>
#
# </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div style="
# padding:13px 15px;
# border-radius:13px;
# background:#FFF7F7;
# border-left:4px solid #DB2777;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# color:#DB2777;
# letter-spacing:1.2px;
# margin-bottom:4px;
# ">
# INVALID INPUT RESULT
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.65;
# color:#475569;
# ">
# An empty
# <span style="color:#2563EB;font-weight:800;">review</span>
# was submitted to the
# <span style="color:#DB2777;font-weight:800;">POST /predict</span>
# endpoint.
#
# Pydantic rejected the request with a
# <span style="color:#DB2777;font-weight:800;">422 Unprocessable Content</span>
# response because the review did not satisfy the required
# <span style="color:#7C3AED;font-weight:800;">minimum length of 3 characters</span>.
#
# The invalid input was therefore blocked before reaching the prediction model.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:22px 24px;
# border-radius:18px;
# background:linear-gradient(135deg,#7C3AED,#A855F7,#EC4899);
# box-shadow:0 10px 28px rgba(124,58,237,.18);
# font-family:'Trebuchet MS',sans-serif;
# margin:20px 0 24px 0;
# text-align:center;
# ">
#
# <div style="
# font-size:25px;
# font-weight:900;
# color:#FFFFFF;
# letter-spacing:.5px;
# ">
# ✓ HANDS-ON LAB COMPLETE
# </div>
#
# <div style="
# font-size:13.5px;
# color:#FDF4FF;
# margin-top:7px;
# ">
# The FastAPI sentiment prediction service was successfully built, tested, and validated.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:20px 22px;
# border-radius:18px;
# background:linear-gradient(135deg,#FFF9FC,#F7F3FF,#EEF6FF,#FFFFFF);
# border:1px solid #E8D9FF;
# box-shadow:0 8px 22px rgba(168,85,247,.07);
# font-family:'Trebuchet MS',sans-serif;
# margin:20px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.5px;
# color:#8B5CF6;
# margin-bottom:6px;
# ">
# DAY 2 · SUMMARY
# </div>
#
# <div style="
# font-size:22px;
# font-weight:850;
# color:#1E293B;
# margin-bottom:14px;
# ">
# Serving the IMDb Sentiment Model with FastAPI
# </div>
#
# <table style="
# width:100%;
# border-collapse:separate;
# border-spacing:0;
# overflow:hidden;
# border-radius:14px;
# background:#FFFFFF;
# border:1px solid #E9E2F1;
# font-size:13.5px;
# color:#475569;
# ">
#
# <tr style="background:linear-gradient(90deg,#F5EEFF,#FFF3F8,#EEF5FF);">
# <th style="padding:11px;text-align:left;color:#7C3AED;">PART</th>
# <th style="padding:11px;text-align:left;color:#7C3AED;">WHAT WAS COMPLETED</th>
# <th style="padding:11px;text-align:left;color:#7C3AED;">RESULT</th>
# </tr>
#
# <tr>
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#7C3AED;">
# Step 1
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Loaded the saved
# <b>Logistic Regression model</b>
# and fitted
# <b>TF-IDF vectorizer</b>
# from Day 1.
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;color:#059669;font-weight:800;">
# ✓ Artifacts loaded
# </td>
# </tr>
#
# <tr style="background:#FCFAFF;">
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#2563EB;">
# Step 2
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Created a
# <b>Pydantic ReviewInput schema</b>
# with validation requiring a review length between
# <b>3 and 5000 characters</b>.
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;color:#059669;font-weight:800;">
# ✓ Validated input
# </td>
# </tr>
#
# <tr>
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#059669;">
# Step 3
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Built the
# <b>POST /predict</b>
# endpoint using the same preprocessing,
# TF-IDF transformation,
# and trained model.
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;color:#7C3AED;font-weight:800;">
# Prediction + Confidence
# </td>
# </tr>
#
# <tr style="background:#FCFAFF;">
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#2563EB;">
# Health Check
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Added and tested the
# <b>GET /health</b>
# endpoint to confirm that the FastAPI service is running and the model is loaded.
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# <span style="color:#059669;font-weight:800;">200</span> →
# <span style="color:#2563EB;font-weight:800;">Healthy</span>
# </td>
# </tr>
#
# <tr>
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#D97706;">
# Positive Test
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Submitted a positive movie review through
# <b>POST /predict</b>.
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# <span style="color:#059669;font-weight:800;">200</span> →
# <span style="color:#7C3AED;font-weight:800;">Positive</span>
# <br>
# <span style="color:#D97706;font-weight:800;">Confidence: 0.9813</span>
# </td>
# </tr>
#
# <tr style="background:#FCFAFF;">
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#DB2777;">
# Negative Test
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Submitted a negative movie review through
# <b>POST /predict</b>.
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# <span style="color:#059669;font-weight:800;">200</span> →
# <span style="color:#DB2777;font-weight:800;">Negative</span>
# <br>
# <span style="color:#D97706;font-weight:800;">Confidence: 0.9975</span>
# </td>
# </tr>
#
# <tr>
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#DB2777;">
# Invalid Input
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Submitted an empty review that did not satisfy the
# <b>minimum length requirement</b>.
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# <span style="color:#DB2777;font-weight:800;">
# 422 Unprocessable Content
# </span>
# </td>
# </tr>
#
# <tr style="background:#FCFAFF;">
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#D97706;">
# Confidence Score
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Extended the API response to include the model's prediction confidence together with the sentiment label.
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# <span style="color:#7C3AED;font-weight:800;">
# Prediction + Confidence
# </span>
# </td>
# </tr>
#
# <tr>
# <td style="padding:11px;border-top:1px solid #EEE8F3;font-weight:800;color:#059669;">
# Final Outcome
# </td>
# <td style="padding:11px;border-top:1px solid #EEE8F3;">
# Completed an end-to-end IMDb sentiment prediction service using
# <b>FastAPI</b>,
# <b>Pydantic</b>,
# the saved
# <b>TF-IDF vectorizer</b>,
# and the trained
# <b>Logistic Regression model</b>.
# </td>
# <td style="
# padding:11px;
# border-top:1px solid #EEE8F3;
# color:#059669;
# font-weight:800;
# ">
# ✓ Successfully served, validated & tested
# </td>
# </tr>
#
# </table>
#
# </div>

# %% [markdown]
# <div style="
# padding:22px 24px;
# border-radius:18px;
# background:linear-gradient(135deg,#7C3AED,#A855F7,#EC4899);
# box-shadow:0 10px 28px rgba(124,58,237,.18);
# font-family:'Trebuchet MS',sans-serif;
# margin:22px 0 8px 0;
# text-align:center;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.6px;
# color:#F5D0FE;
# margin-bottom:6px;
# ">
# DAY 2 COMPLETE
# </div>
#
# <div style="
# font-size:25px;
# font-weight:900;
# color:#FFFFFF;
# letter-spacing:.5px;
# margin-bottom:8px;
# ">
# ✓ Serving the Model with FastAPI
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.7;
# color:#FDF4FF;
# max-width:850px;
# margin:0 auto;
# ">
# The IMDb sentiment model was successfully deployed as a
# <b>FastAPI service</b>,
# with
# <b>Pydantic input validation</b>,
# a
# <b>health-check endpoint</b>,
# and
# <b>confidence-aware sentiment predictions</b>.
# </div>
#
# </div>
