# %% [markdown]
# <div style="
#     padding:26px 28px;
#     border-radius:22px;
#     background:linear-gradient(135deg,#FFF8FC,#F7F3FF,#EEF6FF,#FFFFFF);
#     border:1px solid #E9D5FF;
#     box-shadow:0 12px 28px rgba(168,85,247,.10);
#     margin:18px 0 22px 0;
# ">
#
# <div style="
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:1.8px;
#     color:#A855F7;
#     margin-bottom:8px;
# ">
# WEEK 9 · DAY 1
# </div>
#
# <div style="
#     font-size:30px;
#     font-weight:900;
#     line-height:1.25;
#     margin-bottom:10px;
#     background:linear-gradient(90deg,#7C3AED,#C026D3,#EC4899,#8B5CF6);
#     -webkit-background-clip:text;
#     -webkit-text-fill-color:transparent;
# ">
# Sprint 4 Planning, Serialization & MLOps
# </div>
#
# <div style="
#     width:110px;
#     height:4px;
#     border-radius:999px;
#     background:linear-gradient(90deg,#8B5CF6,#EC4899,#C084FC);
#     margin:4px 0 16px 0;
#     box-shadow:0 0 12px rgba(236,72,153,.35);
# "></div>
#
# <div style="
#     font-size:14px;
#     line-height:1.65;
#     color:#64748B;
# ">
# Today, we begin <b>Sprint 4</b> by preparing the trained IMDb sentiment model for deployment.
#
# We will define the deployment plan, serialize the trained model and preprocessing objects, and review the reproducibility practices needed before serving the model in a real application.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E5E7EB;
#     border-radius:17px;
#     padding:19px 21px;
#     margin:18px 0;
#     box-shadow:0 6px 18px rgba(15,23,42,.04);
# ">
#
# <div style="
#     font-size:20px;
#     font-weight:850;
#     color:#6D28D9;
#     margin-bottom:15px;
# ">
#  Learning Objectives
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.8;
#     color:#475569;
# ">
#
# <div style="margin-bottom:8px;">
# <span style="display:inline-block;min-width:42px;color:#7C3AED;font-weight:900;">01</span>
# <span style="color:#7C3AED;font-weight:800;">Plan Sprint 4</span>
# by defining the deployment goal and the main backlog tasks.
# </div>
#
# <div style="margin-bottom:8px;">
# <span style="display:inline-block;min-width:42px;color:#2563EB;font-weight:900;">02</span>
# <span style="color:#2563EB;font-weight:800;">Serialize the Model</span>
# and save all required preprocessing objects for production use.
# </div>
#
# <div style="margin-bottom:8px;">
# <span style="display:inline-block;min-width:42px;color:#DB2777;font-weight:900;">03</span>
# <span style="color:#DB2777;font-weight:800;">Verify Reproducibility</span>
# by loading the saved artifacts and reproducing a known prediction.
# </div>
#
# <div>
# <span style="display:inline-block;min-width:42px;color:#059669;font-weight:900;">04</span>
# <span style="color:#059669;font-weight:800;">Prepare the Environment</span>
# using pinned dependencies and reproducibility practices before deployment.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#FAF5FF,#FDF2F8,#EFF6FF);
#     border:1px solid #E9D5FF;
#     border-radius:17px;
#     padding:17px 20px;
#     margin:18px 0;
# ">
#
# <div style="
#     font-size:18px;
#     font-weight:850;
#     color:#6D28D9;
#     margin-bottom:13px;
# ">
# ✦ Today's Flow
# </div>
#
# <div style="
#     display:flex;
#     flex-wrap:wrap;
#     align-items:center;
#     justify-content:center;
#     gap:8px;
#     font-size:13px;
#     text-align:center;
# ">
#
# <span style="
#     background:#F5F3FF;
#     border:1px solid #DDD6FE;
#     color:#6D28D9;
#     font-weight:750;
#     padding:9px 13px;
#     border-radius:12px;
# ">
# Sprint Planning
# </span>
#
# <span style="color:#A855F7;font-size:18px;">→</span>
#
# <span style="
#     background:#EFF6FF;
#     border:1px solid #BFDBFE;
#     color:#1D4ED8;
#     font-weight:750;
#     padding:9px 13px;
#     border-radius:12px;
# ">
# Model Serialization
# </span>
#
# <span style="color:#EC4899;font-size:18px;">→</span>
#
# <span style="
#     background:#FDF2F8;
#     border:1px solid #FBCFE8;
#     color:#BE185D;
#     font-weight:750;
#     padding:9px 13px;
#     border-radius:12px;
# ">
# Save Preprocessing
# </span>
#
# <span style="color:#10B981;font-size:18px;">→</span>
#
# <span style="
#     background:#ECFDF5;
#     border:1px solid #A7F3D0;
#     color:#047857;
#     font-weight:750;
#     padding:9px 13px;
#     border-radius:12px;
# ">
# Reproducibility
# </span>
#
# <span style="color:#F59E0B;font-size:18px;">→</span>
#
# <span style="
#     background:#FFFBEB;
#     border:1px solid #FDE68A;
#     color:#B45309;
#     font-weight:750;
#     padding:9px 13px;
#     border-radius:12px;
# ">
# Deployment Ready
# </span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     padding:20px 22px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#FFF9FC,#F7F3FF,#EEF6FF,#FFFFFF);
#     border:1px solid #E8D9FF;
#     box-shadow:0 8px 22px rgba(168,85,247,.07);
#     margin:18px 0;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
#     color:#9333EA;
#     margin-bottom:6px;
# ">
# 1.1
# </div>
#
# <div style="
#     font-size:22px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:8px;
# ">
# Sprint 4 Planning
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# Sprint 4 begins by defining one clear goal:
# <b>turn the trained model into a live, usable application</b>.
#
# Instead of focusing on training a new model, this sprint focuses on
# planning the work required to
# <span style="color:#7C3AED;font-weight:700;">serialize</span>,
# <span style="color:#2563EB;font-weight:700;">serve</span>,
# <span style="color:#DB2777;font-weight:700;">deploy</span>,
# and
# <span style="color:#059669;font-weight:700;">polish</span>
# the existing model.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#EFF6FF;
#     border-left:4px solid #3B82F6;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:16px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#1D4ED8;
#     margin-bottom:5px;
# ">
# Sprint 4 Goal
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.5;
#     color:#475569;
# ">
# Deploy the existing IMDb sentiment model as a
# <b>live public application</b>
# that can receive user input and return predictions reliably.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E5E7EB;
#     border-radius:16px;
#     padding:17px 18px;
#     margin:18px 0;
#     box-shadow:0 5px 15px rgba(15,23,42,.04);
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:850;
#     color:#334155;
#     margin-bottom:10px;
# ">
# Sprint 4 Backlog
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.7;
#     color:#475569;
# ">
#
# <div style="margin-bottom:7px;">
# <span style="color:#7C3AED;font-weight:800;">01 — Serialize</span>
# the trained model and all preprocessing objects.
# </div>
#
# <div style="margin-bottom:7px;">
# <span style="color:#2563EB;font-weight:800;">02 — Serve</span>
# the model through a prediction API.
# </div>
#
# <div style="margin-bottom:7px;">
# <span style="color:#DB2777;font-weight:800;">03 — Build UI</span>
# so a non-technical user can interact with the model.
# </div>
#
# <div style="margin-bottom:7px;">
# <span style="color:#059669;font-weight:800;">04 — Deploy</span>
# the application to a public URL.
# </div>
#
# <div>
# <span style="color:#D97706;font-weight:800;">05 — Polish</span>
# the repository, documentation, and final project artifacts.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     padding:20px 22px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#FFF8FC,#F7F3FF,#EEF6FF,#FFFFFF);
#     border:1px solid #E8D9FF;
#     box-shadow:0 8px 22px rgba(168,85,247,.07);
#     margin:20px 0;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
#     color:#9333EA;
#     margin-bottom:6px;
# ">
# 1.2
# </div>
#
# <div style="
#     font-size:22px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:8px;
# ">
# Why Deployment Matters
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# A trained model inside a notebook is useful for experimentation, but it is not yet accessible to real users.
#
# <span style="color:#7C3AED;font-weight:700;">Deployment</span>
# turns the model into a usable application or service that can receive input and return predictions outside the notebook environment.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#FFFFFF,#FAF7FF,#F8FAFF);
#     border:1px solid #E9D5FF;
#     border-radius:20px;
#     padding:24px 26px;
#     margin:22px 0;
#     box-shadow:0 10px 24px rgba(76,29,149,.06);
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.6px;
#     color:#8B5CF6;
#     margin-bottom:6px;
# ">
# DEPLOYMENT PIPELINE
# </div>
#
# <div style="
#     font-size:20px;
#     font-weight:900;
#     color:#1E293B;
#     margin-bottom:6px;
# ">
# From Notebook to Live Application
# </div>
#
# <div style="
#     font-size:12.5px;
#     line-height:1.55;
#     color:#64748B;
#     margin-bottom:24px;
# ">
# The trained IMDb model moves through a sequence of deployment stages until it becomes accessible to real users.
# </div>
#
# <div style="
#     display:flex;
#     align-items:center;
#     justify-content:space-between;
#     gap:8px;
# ">
#
# <div style="text-align:center;flex:1;">
#     <div style="
#         width:42px;
#         height:42px;
#         border-radius:50%;
#         margin:0 auto 9px auto;
#         background:#F5F3FF;
#         border:2px solid #C4B5FD;
#         display:flex;
#         align-items:center;
#         justify-content:center;
#         color:#6D28D9;
#         font-weight:900;
#         font-size:13px;
#     ">01</div>
#     <div style="font-size:13px;font-weight:850;color:#334155;">Notebook</div>
#     <div style="font-size:11px;color:#94A3B8;margin-top:3px;">Train & evaluate</div>
# </div>
#
# <div style="height:2px;background:#DDD6FE;flex:.45;"></div>
#
# <div style="text-align:center;flex:1;">
#     <div style="
#         width:42px;
#         height:42px;
#         border-radius:50%;
#         margin:0 auto 9px auto;
#         background:#EFF6FF;
#         border:2px solid #BFDBFE;
#         display:flex;
#         align-items:center;
#         justify-content:center;
#         color:#2563EB;
#         font-weight:900;
#         font-size:13px;
#     ">02</div>
#     <div style="font-size:13px;font-weight:850;color:#334155;">Serialization</div>
#     <div style="font-size:11px;color:#94A3B8;margin-top:3px;">Save artifacts</div>
# </div>
#
# <div style="height:2px;background:#E9D5FF;flex:.45;"></div>
#
# <div style="text-align:center;flex:1;">
#     <div style="
#         width:42px;
#         height:42px;
#         border-radius:50%;
#         margin:0 auto 9px auto;
#         background:#FDF2F8;
#         border:2px solid #FBCFE8;
#         display:flex;
#         align-items:center;
#         justify-content:center;
#         color:#DB2777;
#         font-weight:900;
#         font-size:13px;
#     ">03</div>
#     <div style="font-size:13px;font-weight:850;color:#334155;">FastAPI</div>
#     <div style="font-size:11px;color:#94A3B8;margin-top:3px;">Serve predictions</div>
# </div>
#
# <div style="height:2px;background:#D1FAE5;flex:.45;"></div>
#
# <div style="text-align:center;flex:1;">
#     <div style="
#         width:42px;
#         height:42px;
#         border-radius:50%;
#         margin:0 auto 9px auto;
#         background:#ECFDF5;
#         border:2px solid #A7F3D0;
#         display:flex;
#         align-items:center;
#         justify-content:center;
#         color:#059669;
#         font-weight:900;
#         font-size:13px;
#     ">04</div>
#     <div style="font-size:13px;font-weight:850;color:#334155;">Streamlit</div>
#     <div style="font-size:11px;color:#94A3B8;margin-top:3px;">User interface</div>
# </div>
#
# <div style="height:2px;background:#FDE68A;flex:.45;"></div>
#
# <div style="text-align:center;flex:1;">
#     <div style="
#         width:42px;
#         height:42px;
#         border-radius:50%;
#         margin:0 auto 9px auto;
#         background:#FFFBEB;
#         border:2px solid #FDE68A;
#         display:flex;
#         align-items:center;
#         justify-content:center;
#         color:#D97706;
#         font-weight:900;
#         font-size:13px;
#     ">05</div>
#     <div style="font-size:13px;font-weight:850;color:#334155;">Public URL</div>
#     <div style="font-size:11px;color:#94A3B8;margin-top:3px;">Real users</div>
# </div>
#
# </div>
#
# <div style="
#     margin-top:24px;
#     padding-top:14px;
#     border-top:1px solid #EEF2F7;
#     font-size:12px;
#     color:#64748B;
#     line-height:1.55;
# ">
# <b style="color:#4C1D95;">Sprint 4 focus:</b>
# package the existing model, expose it through an API, add a usable interface, and deploy it publicly.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     padding:20px 22px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#FFF9FC,#F7F3FF,#EEF6FF,#FFFFFF);
#     border:1px solid #E8D9FF;
#     box-shadow:0 8px 22px rgba(168,85,247,.07);
#     margin:20px 0;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
#     color:#9333EA;
#     margin-bottom:6px;
# ">
# 1.3
# </div>
#
# <div style="
#     font-size:22px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:8px;
# ">
# Model Serialization
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# Before a trained model can be used by another application, it must be saved to disk.
#
# <span style="color:#7C3AED;font-weight:700;">Serialization</span>
# is the process of saving a trained model and its required preprocessing objects so they can be loaded later
# without retraining the model from scratch.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     display:grid;
#     grid-template-columns:1fr 1fr;
#     gap:12px;
#     margin:18px 0;
# ">
#
# <div style="
#     background:#F5F3FF;
#     border:1px solid #DDD6FE;
#     border-radius:15px;
#     padding:15px;
# ">
# <div style="font-size:15px;font-weight:800;color:#6D28D9;margin-bottom:6px;">
# Training Stage
# </div>
# <div style="font-size:13px;line-height:1.5;color:#475569;">
# Train the model and preprocessing objects once.
# </div>
# </div>
#
# <div style="
#     background:#ECFDF5;
#     border:1px solid #A7F3D0;
#     border-radius:15px;
#     padding:15px;
# ">
# <div style="font-size:15px;font-weight:800;color:#047857;margin-bottom:6px;">
# Deployment Stage
# </div>
# <div style="font-size:13px;line-height:1.5;color:#475569;">
# Load the saved files and use them directly for prediction.
# </div>
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E5E7EB;
#     border-radius:16px;
#     padding:17px 18px;
#     margin:18px 0;
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:850;
#     color:#334155;
#     margin-bottom:10px;
# ">
# What Should We Save?
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.65;
#     color:#475569;
# ">
#
# For the IMDb sentiment project, deployment depends on more than the trained classifier.
#
# <div style="margin-top:9px;">
# <span style="color:#7C3AED;font-weight:800;">Model:</span>
# the trained Logistic Regression classifier.
# </div>
#
# <div style="margin-top:7px;">
# <span style="color:#2563EB;font-weight:800;">Vectorizer:</span>
# the fitted TF-IDF vectorizer that converts processed reviews into the same feature space used during training.
# </div>
#
# <div style="margin-top:7px;">
# <span style="color:#DB2777;font-weight:800;">Preprocessing Logic:</span>
# the same text-cleaning steps used before vectorization must also be preserved for deployment.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     margin-top:10px;
#     padding:10px 12px;
#     background:#FFF7ED;
#     border:1px solid #FED7AA;
#     border-radius:10px;
#     font-size:12px;
#     line-height:1.5;
#     color:#475569;
# ">
# <b style="color:#C2410C;">Deployment Note:</b>
# The TF-IDF vectorizer is saved as an artifact, while the
# <b>preprocess_review()</b> function must also be available in the serving application.
# It should be reused exactly as defined during training to avoid preprocessing differences.
# </div>

# %% [markdown]
# <div style="
#     background:#FFF7ED;
#     border-left:4px solid #F59E0B;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:16px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#B45309;
#     margin-bottom:5px;
# ">
# Important
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.5;
#     color:#475569;
# ">
# Saving only the model is not enough.
#
# The deployment application must use the
# <b>same TF-IDF vectorizer and the same preprocessing pipeline</b>
# used during training, otherwise the model may receive different inputs from the ones it learned from.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E5E7EB;
#     border-radius:18px;
#     padding:20px 22px;
#     margin:20px 0;
#     box-shadow:0 6px 18px rgba(15,23,42,.04);
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.4px;
#     color:#8B5CF6;
#     margin-bottom:6px;
# ">
# SERIALIZATION FLOW
# </div>
#
# <div style="
#     font-size:18px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:16px;
# ">
# How the Saved Model Is Reused
# </div>
#
# <div style="
#     display:grid;
#     grid-template-columns:repeat(4,1fr);
#     gap:10px;
# ">
#
# <div style="
#     background:#F8FAFC;
#     border-radius:12px;
#     padding:13px;
# ">
# <div style="font-size:11px;font-weight:800;color:#7C3AED;">STEP 01</div>
# <div style="font-size:14px;font-weight:850;color:#334155;margin-top:4px;">Train</div>
# <div style="font-size:11px;color:#64748B;margin-top:4px;">
# Train the Logistic Regression model and TF-IDF vectorizer.
# </div>
# </div>
#
# <div style="
#     background:#F8FAFC;
#     border-radius:12px;
#     padding:13px;
# ">
# <div style="font-size:11px;font-weight:800;color:#2563EB;">STEP 02</div>
# <div style="font-size:14px;font-weight:850;color:#334155;margin-top:4px;">Save</div>
# <div style="font-size:11px;color:#64748B;margin-top:4px;">
# Store the trained objects using joblib.
# </div>
# </div>
#
# <div style="
#     background:#F8FAFC;
#     border-radius:12px;
#     padding:13px;
# ">
# <div style="font-size:11px;font-weight:800;color:#DB2777;">STEP 03</div>
# <div style="font-size:14px;font-weight:850;color:#334155;margin-top:4px;">Load</div>
# <div style="font-size:11px;color:#64748B;margin-top:4px;">
# Restore the saved model and vectorizer from disk.
# </div>
# </div>
#
# <div style="
#     background:#F8FAFC;
#     border-radius:12px;
#     padding:13px;
# ">
# <div style="font-size:11px;font-weight:800;color:#059669;">STEP 04</div>
# <div style="font-size:14px;font-weight:850;color:#334155;margin-top:4px;">Predict</div>
# <div style="font-size:11px;color:#64748B;margin-top:4px;">
# Use the loaded artifacts without retraining.
# </div>
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#F5F3FF,#EFF6FF,#FFFFFF);
#     border:1px solid #DDD6FE;
#     border-radius:15px;
#     padding:14px 17px;
#     margin:18px 0 12px 0;
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:800;
#     color:#6D28D9;
#     margin-bottom:6px;
# ">
# Saving and Loading with joblib
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# For scikit-learn models, <b>joblib</b> can be used to save trained objects to disk and load them again later.
#
# This allows the deployment application to reuse the trained model and vectorizer without repeating the training process.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#F8FAFC,#F5F3FF,#FFFFFF);
#     border:1px solid #E2E8F0;
#     border-radius:14px;
#     padding:13px 16px;
#     margin:18px 0 12px 0;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.3px;
#     color:#7C3AED;
#     margin-bottom:5px;
# ">
# SETUP
# </div>
#
# <div style="
#     font-size:16px;
#     font-weight:850;
#     color:#334155;
#     margin-bottom:5px;
# ">
# Restore the IMDb Workflow
# </div>
#
# <div style="
#     font-size:12.5px;
#     line-height:1.5;
#     color:#64748B;
# ">
# To serialize the trained artifacts in this notebook, we first recreate the same preprocessing,
# TF-IDF, and Logistic Regression workflow used in the previous stage.
# </div>
#
# </div>

# %%
import pandas as pd
from pathlib import Path

data_path = Path("IMDB Dataset.csv")

df = pd.read_csv(data_path)
df = df.drop_duplicates().reset_index(drop=True)

print("Dataset loaded successfully.")
print("Shape:", df.shape)
df.head()
# Out:
# Dataset loaded successfully.
# Shape: (49582, 2)
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
import re
import html
import nltk

from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

resources = [
    "punkt",
    "punkt_tab",
    "stopwords",
    "wordnet",
    "omw-1.4",
    "averaged_perceptron_tagger_eng"
]

for resource in resources:
    nltk.download(resource, quiet=True)

negation_words = {"not", "no", "nor"}
stop_words = set(stopwords.words("english")) - negation_words
lemmatizer = WordNetLemmatizer()


def get_wordnet_pos(tag):
    if tag.startswith("J"):
        return wordnet.ADJ
    elif tag.startswith("V"):
        return wordnet.VERB
    elif tag.startswith("N"):
        return wordnet.NOUN
    elif tag.startswith("R"):
        return wordnet.ADV
    else:
        return wordnet.NOUN


def preprocess_review(text):
    text = html.unescape(str(text))
    text = re.sub(r"<[^>]+>", " ", text)
    text = re.sub(r"n['’]t\b", " not", text)
    text = text.lower()
    text = re.sub(r"\d+", " ", text)
    text = re.sub(r"[^\w\s']", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    tokens = word_tokenize(text)

    tokens = [
        token for token in tokens
        if token not in stop_words and len(token) > 1
    ]

    tagged_tokens = pos_tag(tokens)

    lemmas = [
        lemmatizer.lemmatize(word, get_wordnet_pos(tag))
        for word, tag in tagged_tokens
    ]

    lemmas = [
        word for word in lemmas
        if not word.startswith("'")
    ]

    return " ".join(lemmas)


print("Preprocessing pipeline ready.")
# Out:
# Preprocessing pipeline ready.

# %%
# Apply preprocessing to all reviews
df["processed_review"] = df["review"].apply(preprocess_review)

# Convert sentiment labels to numbers
df["label"] = df["sentiment"].map({
    "negative": 0,
    "positive": 1
})

print("Preprocessing completed.")
print(df[["sentiment", "label", "processed_review"]].head())
# Out:
# Preprocessing completed.
#   sentiment  label                                   processed_review
# 0  positive      1  one reviewer mention watch oz episode hook rig...
# 1  positive      1  wonderful little production film technique una...
# 2  positive      1  think wonderful way spend time hot summer week...
# 3  negative      0  basically family little boy jake think zombie ...
# 4  positive      1  petter mattei love time money visually stunnin...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test, y_train, y_test = train_test_split(
    df["processed_review"],
    df["label"],
    test_size=0.2,
    random_state=42,
    stratify=df["label"]
)

vectorizer = TfidfVectorizer(max_features=5000)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("TF-IDF ready.")
print("Training shape:", X_train_tfidf.shape)
print("Testing shape:", X_test_tfidf.shape)
# Out:
# TF-IDF ready.
# Training shape: (39665, 5000)
# Testing shape: (9917, 5000)

# %%
from sklearn.linear_model import LogisticRegression

baseline_model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

baseline_model.fit(X_train_tfidf, y_train)

print("Logistic Regression model trained successfully.")
# Out:
# Logistic Regression model trained successfully.

# %% [markdown]
# <div style="
#     background:#F8FAFC;
#     border-left:4px solid #8B5CF6;
#     border-radius:0 10px 10px 0;
#     padding:11px 14px;
#     margin:12px 0 16px 0;
#     font-size:12.5px;
#     line-height:1.5;
#     color:#475569;
# ">
# <b style="color:#6D28D9;">Why retrain here?</b>
# This step recreates the final IMDb workflow inside the current notebook so the trained model and fitted vectorizer can be serialized for deployment.
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#F5F3FF,#EFF6FF,#FFFFFF);
#     border:1px solid #DDD6FE;
#     border-radius:15px;
#     padding:14px 17px;
#     margin:18px 0 12px 0;
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:800;
#     color:#6D28D9;
#     margin-bottom:6px;
# ">
# Serialize the Trained Model
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# Now that the Logistic Regression model and TF-IDF vectorizer are trained,
# we save both objects to disk using <b>joblib</b>.
#
# This allows the deployment application to load the trained components later
# without retraining the model every time.
# </div>
#
# </div>

# %%
import joblib

joblib.dump(baseline_model, "model.joblib")
joblib.dump(vectorizer, "vectorizer.joblib")

print("Model and vectorizer saved successfully.")
# Out:
# Model and vectorizer saved successfully.

# %% [markdown]
# <div style="
#     background:#EFF6FF;
#     border-left:4px solid #3B82F6;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:16px 0 12px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#1D4ED8;
#     margin-bottom:5px;
# ">
# Verify the Saved Artifacts
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.5;
#     color:#475569;
# ">
# After saving the model and vectorizer, we load them back from disk.
#
# This verifies that the serialized files can be restored correctly and reused for prediction without retraining the model.
# </div>
#
# </div>

# %%
loaded_model = joblib.load("model.joblib")
loaded_vectorizer = joblib.load("vectorizer.joblib")

print("Model and vectorizer loaded successfully.")
# Out:
# Model and vectorizer loaded successfully.

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#ECFDF5,#F0FDFA,#FFFFFF);
#     border:1px solid #A7F3D0;
#     border-radius:15px;
#     padding:14px 17px;
#     margin:18px 0 12px 0;
# ">
#
# <div style="
#     font-size:15px;
#     font-weight:800;
#     color:#047857;
#     margin-bottom:6px;
# ">
# Reproduce a Known Prediction
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# To confirm that serialization worked correctly, we use the
# <b>loaded model</b> and
# <b>loaded vectorizer</b>
# to make a new sentiment prediction.
#
# If the saved artifacts work correctly after loading, they are ready to be used later by the deployment application.
# </div>
#
# </div>

# %%
sample_review = "This movie was absolutely amazing and I loved every minute of it."

cleaned_review = preprocess_review(sample_review)

sample_vector = loaded_vectorizer.transform([cleaned_review])

prediction = loaded_model.predict(sample_vector)[0]

sentiment = "Positive" if prediction == 1 else "Negative"

print("Review:", sample_review)
print("Prediction:", sentiment)
# Out:
# Review: This movie was absolutely amazing and I loved every minute of it.
# Prediction: Positive

# %% [markdown]
# <div style="
#     background:#ECFDF5;
#     border-left:4px solid #10B981;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:12px 0 20px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#047857;
#     margin-bottom:5px;
# ">
# Observation
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# The loaded model and TF-IDF vectorizer successfully produced a valid sentiment prediction.
#
# The sample review was classified as <b>Positive</b>, confirming that the serialized artifacts can be restored and reused without retraining.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     padding:20px 22px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#FFF9FC,#F7F3FF,#EEF6FF,#FFFFFF);
#     border:1px solid #E8D9FF;
#     box-shadow:0 8px 22px rgba(168,85,247,.07);
#     margin:20px 0;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.5px;
#     color:#9333EA;
#     margin-bottom:6px;
# ">
# 1.4
# </div>
#
# <div style="
#     font-size:22px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:8px;
# ">
# MLOps & Reproducibility Recap
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# Before deployment, the project must be
# <span style="color:#7C3AED;font-weight:700;">reproducible</span>.
#
# This means the model should behave consistently when the project is run again on another machine or deployment environment.
#
# Three practices are especially important:
# <b>pinned dependencies</b>,
# <b>experiment tracking</b>,
# and
# <b>fixed random seeds</b>.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E5E7EB;
#     border-radius:16px;
#     padding:17px 18px;
#     margin:18px 0;
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:850;
#     color:#334155;
#     margin-bottom:8px;
# ">
# Pinned Dependencies
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# A deployment environment needs to install the same libraries used during development.
#
# A <b>requirements.txt</b> file lists the required packages and their versions so the project can be reproduced consistently on another machine or hosting platform.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#EFF6FF;
#     border-left:4px solid #3B82F6;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:14px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#1D4ED8;
#     margin-bottom:5px;
# ">
# Why Pin Versions?
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.5;
#     color:#475569;
# ">
# Different library versions can behave differently.
#
# Pinning versions reduces the chance that the model works locally but fails or behaves differently after deployment.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#FFF7ED,#FFFBEB,#FFFFFF);
#     border:1px solid #FED7AA;
#     border-radius:15px;
#     padding:14px 17px;
#     margin:18px 0;
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:800;
#     color:#C2410C;
#     margin-bottom:6px;
# ">
# Fixed Random Seeds
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# Some machine-learning operations include randomness, such as data splitting or model initialization.
#
# Using a <b>fixed random seed</b> helps reproduce the same results when the experiment is run again.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#ECFDF5;
#     border-left:4px solid #10B981;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:14px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#047857;
#     margin-bottom:5px;
# ">
# In Our IMDb Project
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.5;
#     color:#475569;
# ">
# We already use <b>random_state = 42</b> in the train/test split and Logistic Regression setup.
#
# This helps keep the workflow reproducible and makes evaluation results more consistent across repeated runs.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#F5F3FF,#EFF6FF,#FFFFFF);
#     border:1px solid #DDD6FE;
#     border-radius:15px;
#     padding:14px 17px;
#     margin:18px 0;
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:800;
#     color:#6D28D9;
#     margin-bottom:6px;
# ">
# Experiment Tracking with MLflow
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# During model development, different experiments may use different parameters, preprocessing choices, or model versions.
#
# <b>MLflow</b> helps track these experiments by recording model settings, metrics, and results so each run can be reviewed and reproduced later.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#F8FAFC;
#     border-left:4px solid #94A3B8;
#     border-radius:0 10px 10px 0;
#     padding:11px 14px;
#     margin:12px 0 16px 0;
#     font-size:12.5px;
#     line-height:1.5;
#     color:#475569;
# ">
# <b style="color:#475569;">Scope Note:</b>
# MLflow is reviewed here as a reproducibility and experiment-tracking concept.
# The Day 1 hands-on focuses on serialization, artifact verification, and pinned dependencies, so no MLflow run is required in this notebook.
# </div>

# %% [markdown]
# <div style="
#     background:#FDF2F8;
#     border-left:4px solid #EC4899;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:14px 0 20px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#BE185D;
#     margin-bottom:5px;
# ">
# Why It Matters for Deployment
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.5;
#     color:#475569;
# ">
# Experiment tracking makes it easier to identify
# <b>which model version</b>
# is being deployed and what performance it achieved during evaluation.
#
# This improves traceability and reduces confusion when multiple model versions exist.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     padding:18px 20px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#312E81,#6D28D9,#9333EA,#DB2777);
#     box-shadow:0 8px 20px rgba(109,40,217,.18);
#     margin:26px 0 16px 0;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.7px;
#     color:#EDE9FE;
#     margin-bottom:5px;
# ">
# PRACTICAL SECTION
# </div>
#
# <div style="
#     font-size:23px;
#     font-weight:900;
#     color:#FFFFFF;
#     margin-bottom:5px;
# ">
# Hands-On Lab
# </div>
#
# <div style="
#     font-size:14px;
#     font-weight:700;
#     color:#FCE7F3;
# ">
# Sprint 4 Kickoff & Serialization
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#F8FAFC;
#     border:1px solid #E2E8F0;
#     border-radius:15px;
#     padding:15px 18px;
#     margin:0 0 22px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#334155;
#     margin-bottom:9px;
# ">
# Hands-On Tasks
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.65;
#     color:#475569;
# ">
#
# <div style="background:#FFFFFF;border-radius:9px;padding:8px 11px;margin-bottom:6px;">
# <b style="color:#6D28D9;">Step 1:</b>
# Define the Sprint 4 deployment goal and backlog.
# </div>
#
# <div style="background:#FFFFFF;border-radius:9px;padding:8px 11px;margin-bottom:6px;">
# <b style="color:#6D28D9;">Step 2:</b>
# Serialize the trained Logistic Regression model and TF-IDF vectorizer.
# </div>
#
# <div style="background:#FFFFFF;border-radius:9px;padding:8px 11px;margin-bottom:6px;">
# <b style="color:#6D28D9;">Step 3:</b>
# Load the saved artifacts and reproduce a known prediction.
# </div>
#
# <div style="background:#FFFFFF;border-radius:9px;padding:8px 11px;">
# <b style="color:#6D28D9;">Step 4:</b>
# Prepare a pinned requirements.txt for deployment.
# </div>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#F5F3FF,#EFF6FF,#FFFFFF);
#     border:1px solid #DDD6FE;
#     border-radius:15px;
#     padding:14px 17px;
#     margin:18px 0 12px 0;
# ">
#
# <div style="
#     font-size:16px;
#     font-weight:800;
#     color:#6D28D9;
#     margin-bottom:6px;
# ">
# Prepare requirements.txt
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# The deployment environment must install the libraries required by the IMDb sentiment application.
#
# A pinned <b>requirements.txt</b> records the exact package versions used in the current environment, helping keep deployment reproducible.
# </div>
#
# </div>

# %%
import importlib.metadata as metadata

packages = [
    "pandas",
    "numpy",
    "scikit-learn",
    "nltk",
    "joblib"
]

requirements = []

for package in packages:
    version = metadata.version(package)
    requirements.append(f"{package}=={version}")

with open("requirements.txt", "w") as file:
    file.write("\n".join(requirements))

print("requirements.txt created successfully.\n")

with open("requirements.txt", "r") as file:
    print(file.read())
# Out:
# requirements.txt created successfully.
#
# pandas==3.0.3
# numpy==2.5.1
# scikit-learn==1.9.0
# nltk==3.10.3
# joblib==1.5.3

# %% [markdown]
# <div style="
#     background:#ECFDF5;
#     border-left:4px solid #10B981;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:12px 0 20px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#047857;
#     margin-bottom:5px;
# ">
# Observation
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# The <b>requirements.txt</b> file was created successfully using the exact package versions installed in the current environment.
#
# Pinning these versions improves reproducibility and helps the deployment environment recreate the same software setup used during development.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFF7ED;
#     border-left:4px solid #F59E0B;
#     border-radius:0 10px 10px 0;
#     padding:11px 14px;
#     margin:12px 0 18px 0;
#     font-size:12.5px;
#     line-height:1.5;
#     color:#475569;
# ">
# <b style="color:#B45309;">Note:</b>
# This requirements file currently contains the dependencies needed for the Day 1 model workflow.
# As the deployment stack expands, additional packages such as FastAPI, Uvicorn, Pydantic, and Streamlit can be added in the following days.
# </div>

# %% [markdown]
# <div style="
#     background:linear-gradient(135deg,#F8FAFF,#F5F3FF,#FFF8FC,#FFFFFF);
#     border:1px solid #DDD6FE;
#     border-radius:18px;
#     padding:18px 20px;
#     margin:20px 0;
#     box-shadow:0 6px 18px rgba(124,58,237,.05);
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.4px;
#     color:#8B5CF6;
#     margin-bottom:6px;
# ">
# DEPLOYMENT READINESS
# </div>
#
# <div style="
#     font-size:18px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:14px;
# ">
# Sprint 4 Day 1 Status
# </div>
#
# <div style="
#     display:grid;
#     grid-template-columns:repeat(4,1fr);
#     gap:10px;
# ">
#
# <div style="
#     background:#ECFDF5;
#     border:1px solid #A7F3D0;
#     border-radius:12px;
#     padding:13px;
# ">
# <div style="font-size:11px;font-weight:800;color:#047857;">MODEL</div>
# <div style="font-size:14px;font-weight:850;color:#334155;margin-top:4px;">Saved</div>
# <div style="font-size:11px;color:#64748B;margin-top:3px;">model.joblib</div>
# </div>
#
# <div style="
#     background:#EFF6FF;
#     border:1px solid #BFDBFE;
#     border-radius:12px;
#     padding:13px;
# ">
# <div style="font-size:11px;font-weight:800;color:#2563EB;">VECTORIZER</div>
# <div style="font-size:14px;font-weight:850;color:#334155;margin-top:4px;">Saved</div>
# <div style="font-size:11px;color:#64748B;margin-top:3px;">vectorizer.joblib</div>
# </div>
#
# <div style="
#     background:#FDF2F8;
#     border:1px solid #FBCFE8;
#     border-radius:12px;
#     padding:13px;
# ">
# <div style="font-size:11px;font-weight:800;color:#BE185D;">VERIFICATION</div>
# <div style="font-size:14px;font-weight:850;color:#334155;margin-top:4px;">Passed</div>
# <div style="font-size:11px;color:#64748B;margin-top:3px;">Known prediction reproduced</div>
# </div>
#
# <div style="
#     background:#FFF7ED;
#     border:1px solid #FED7AA;
#     border-radius:12px;
#     padding:13px;
# ">
# <div style="font-size:11px;font-weight:800;color:#C2410C;">ENVIRONMENT</div>
# <div style="font-size:14px;font-weight:850;color:#334155;margin-top:4px;">Pinned</div>
# <div style="font-size:11px;color:#64748B;margin-top:3px;">requirements.txt</div>
# </div>
#
# </div>
#
# <div style="
#     margin-top:14px;
#     padding:10px 12px;
#     background:#FFFFFF;
#     border:1px solid #E5E7EB;
#     border-radius:10px;
#     font-size:12px;
#     color:#64748B;
# ">
# Day 1 deployment preparation is complete. The saved artifacts can now be reused by the FastAPI service in Day 2.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     padding:18px 20px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#F8FAFF,#F5F3FF,#FFF8FC);
#     border:1px solid #DDD6FE;
#     margin:22px 0 14px 0;
# ">
#
# <div style="
#     font-size:10px;
#     font-weight:800;
#     letter-spacing:1.4px;
#     color:#7C3AED;
#     margin-bottom:5px;
# ">
# DAY 1 SUMMARY
# </div>
#
# <div style="
#     font-size:21px;
#     font-weight:850;
#     color:#1E293B;
#     margin-bottom:7px;
# ">
# Sprint 4 Planning, Serialization & MLOps
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# Today, the IMDb sentiment model was prepared for deployment.
#
# We defined the Sprint 4 deployment goal and backlog, serialized the trained Logistic Regression model and TF-IDF vectorizer, loaded the saved artifacts successfully, and reproduced a valid prediction without retraining.
#
# We also reviewed key reproducibility practices including pinned dependencies, fixed random seeds, and experiment tracking.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#FFFFFF;
#     border:1px solid #E5E7EB;
#     border-radius:14px;
#     padding:14px 17px;
#     margin:12px 0 20px 0;
# ">
#
# <div style="
#     font-size:15px;
#     font-weight:800;
#     color:#334155;
#     margin-bottom:8px;
# ">
# Hands-On Completion
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.7;
#     color:#475569;
# ">
# ✓ <b>Step 1:</b> Defined the Sprint 4 deployment goal and backlog.<br>
# ✓ <b>Step 2:</b> Serialized the trained model and TF-IDF vectorizer using joblib.<br>
# ✓ <b>Step 3:</b> Loaded the saved artifacts and reproduced a known Positive prediction.<br>
# ✓ <b>Step 4:</b> Created a pinned requirements.txt using the current environment versions.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background:#ECFDF5;
#     border-left:4px solid #10B981;
#     border-radius:0 12px 12px 0;
#     padding:13px 16px;
#     margin:12px 0 24px 0;
# ">
#
# <div style="
#     font-size:14px;
#     font-weight:800;
#     color:#047857;
#     margin-bottom:5px;
# ">
# Final Insight
# </div>
#
# <div style="
#     font-size:13px;
#     line-height:1.55;
#     color:#475569;
# ">
# The model is now prepared for the next deployment stage.
#
# Because the trained model, TF-IDF vectorizer, and environment dependencies are saved and reproducible, the next step is to expose the prediction workflow through a <b>FastAPI endpoint</b>.
# </div>
#
# </div>
