# %% [markdown]
# <div style="
#     padding:34px 36px;
#     border-radius:26px;
#     background:
#         radial-gradient(circle at top right, rgba(99,102,241,.16), transparent 34%),
#         radial-gradient(circle at bottom left, rgba(236,72,153,.10), transparent 32%),
#         linear-gradient(135deg,#10131A 0%,#171A24 58%,#202433 100%);
#     border:1px solid rgba(255,255,255,.07);
#     box-shadow:0 20px 50px rgba(0,0,0,.24);
#     font-family:'Trebuchet MS',sans-serif;
#     color:white;
# ">
#
# <div style="
#     font-size:11px;
#     font-weight:800;
#     letter-spacing:2.3px;
#     color:#A5B4FC;
#     margin-bottom:10px;
# ">
# WEEK 09 · DAY 03
# </div>
#
# <div style="
#     font-size:34px;
#     font-weight:900;
#     line-height:1.2;
#     margin-bottom:14px;
# ">
# From Model to
# <span style="color:#C084FC;">Interactive Experience</span>
# </div>
#
# <div style="
#     font-size:15px;
#     line-height:1.85;
#     color:#CBD5E1;
#     max-width:900px;
# ">
# Today, the saved
# <span style="color:#A78BFA;font-weight:800;">IMDb sentiment model</span>
# moves beyond notebooks and API requests into a
# <span style="color:#60A5FA;font-weight:800;">Streamlit interface</span>
# that a real user can interact with directly.
# The application accepts a
# <span style="color:#F472B6;font-weight:800;">movie review</span>,
# processes it through the saved
# <span style="color:#93C5FD;font-weight:800;">TF-IDF vectorizer</span>,
# and returns a clear
# <span style="color:#4ADE80;font-weight:800;">sentiment prediction</span>
# with confidence.
# </div>
#
# <div style="
#     margin-top:24px;
#     padding:13px 16px;
#     border-radius:14px;
#     background:rgba(255,255,255,.045);
#     border:1px solid rgba(255,255,255,.07);
#     font-size:13px;
#     color:#E2E8F0;
# ">
# <span style="color:#A78BFA;font-weight:800;">PROJECT FLOW</span>
# &nbsp;&nbsp;
# Review
# <span style="color:#64748B;">→</span>
# TF-IDF
# <span style="color:#64748B;">→</span>
# Logistic Regression
# <span style="color:#64748B;">→</span>
# Streamlit Result
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:24px 26px;
# border-radius:20px;
# background:linear-gradient(135deg,#F9FAFB,#F5F3FF,#FFF7FB);
# border:1px solid #E5E7EB;
# box-shadow:0 8px 22px rgba(79,70,229,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="font-size:11px;font-weight:800;letter-spacing:1.7px;color:#7C3AED;margin-bottom:7px;">
# INTRODUCTION
# </div>
#
# <div style="font-size:24px;font-weight:900;color:#1F2937;margin-bottom:10px;">
# Turning the IMDb Model into a
# <span style="color:#EC4899;">Real User Experience</span>
# </div>
#
# <div style="font-size:14.5px;line-height:1.85;color:#4B5563;">
# In Day 2, the saved
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>
# was served through
# <span style="color:#2563EB;font-weight:800;">FastAPI</span>.
# Today, the same model is connected to
# <span style="color:#EC4899;font-weight:800;">Streamlit</span>
# to create a simple interface where users can enter a movie review and receive an immediate sentiment prediction.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:24px 26px;
# border-radius:20px;
# background:linear-gradient(135deg,#F8FAFC,#F5F3FF,#FFF7FB);
# border:1px solid #E7E5EF;
# box-shadow:0 8px 22px rgba(79,70,229,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="font-size:11px;font-weight:800;letter-spacing:1.7px;color:#6366F1;margin-bottom:7px;">
# DAY 3 ROADMAP
# </div>
#
# <div style="font-size:24px;font-weight:900;color:#1F2937;margin-bottom:14px;">
# From Saved Model to
# <span style="color:#EC4899;">Interactive Dashboard</span>
# </div>
#
# <div style="font-size:14px;line-height:2;color:#4B5563;">
#
# <span style="color:#7C3AED;font-weight:800;">01</span> — Why Streamlit<br>
# <span style="color:#2563EB;font-weight:800;">02</span> — Streamlit Basics<br>
# <span style="color:#059669;font-weight:800;">03</span> — Common Widgets<br>
# <span style="color:#D97706;font-weight:800;">04</span> — Designing a Usable Demo<br>
# <span style="color:#EC4899;font-weight:800;">05</span> — Build the IMDb Dashboard<br>
# <span style="color:#16A34A;font-weight:800;">06</span> — Test Predictions & Confidence
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:22px 24px;
# border-radius:18px;
# background:linear-gradient(135deg,#EEF2FF,#F5F3FF,#FFF7FB);
# border:1px solid #DDD6FE;
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="font-size:11px;font-weight:800;letter-spacing:1.6px;color:#8B5CF6;margin-bottom:7px;">
# VISUAL OVERVIEW
# </div>
#
# <div style="font-size:22px;font-weight:900;color:#1F2937;margin-bottom:12px;">
# IMDb Sentiment App Flow
# </div>
#
# <div style="
# text-align:center;
# font-size:15px;
# font-weight:800;
# line-height:2;
# ">
#
# <span style="color:#EC4899;">Movie Review</span>
# →
# <span style="color:#2563EB;">TF-IDF</span>
# →
# <span style="color:#7C3AED;">Logistic Regression</span>
# →
# <span style="color:#16A34A;">Sentiment</span>
# →
# <span style="color:#D97706;">Confidence</span>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:22px 24px;
# border-radius:18px;
# background:linear-gradient(135deg,#FFF7FB,#FAF5FF);
# border:1px solid #F3DDEC;
# box-shadow:0 8px 20px rgba(236,72,153,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.6px;
# color:#DB2777;
# margin-bottom:7px;
# ">
# 3.1 · WHY STREAMLIT
# </div>
#
# <div style="
# font-size:23px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:10px;
# ">
# From Model API to
# <span style="color:#EC4899;">User Interface</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.75;
# color:#4B5563;
# ">
# A
# <span style="color:#2563EB;font-weight:800;">FastAPI endpoint</span>
# is designed mainly for programs and external applications.
#
# <span style="color:#EC4899;font-weight:800;">Streamlit</span>
# makes the same machine learning model accessible to people through a simple graphical interface.
#
# For the IMDb project, the user only needs to enter a
# <span style="color:#7C3AED;font-weight:800;">movie review</span>
# and click a button to receive a
# <span style="color:#16A34A;font-weight:800;">sentiment prediction</span>.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:22px 24px;
# border-radius:18px;
# background:linear-gradient(135deg,#F6FAFF,#F8FBFF);
# border:1px solid #DCE9F8;
# box-shadow:0 8px 20px rgba(59,130,246,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.6px;
# color:#2563EB;
# margin-bottom:7px;
# ">
# 3.2 · STREAMLIT BASICS
# </div>
#
# <div style="
# font-size:23px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:10px;
# ">
# Building the Interface with
# <span style="color:#3B82F6;">Python Widgets</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.75;
# color:#4B5563;
# margin-bottom:12px;
# ">
# Streamlit turns simple Python commands into interactive web components.
# For example,
# <span style="color:#2563EB;font-weight:800;">st.title()</span>
# creates a title,
# <span style="color:#2563EB;font-weight:800;">st.text_area()</span>
# accepts text input, and
# <span style="color:#2563EB;font-weight:800;">st.button()</span>
# creates an action button.
# </div>
#
# <div style="
# padding:12px 14px;
# border-radius:13px;
# background:#FFFFFF;
# border:1px solid #E6EEF8;
# font-size:13.5px;
# line-height:1.7;
# color:#475569;
# ">
# When the user interacts with a widget,
# <span style="color:#7C3AED;font-weight:800;">Streamlit reruns the script from top to bottom</span>
# using the latest input values.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:21px 24px;
# border-radius:18px;
# background:linear-gradient(135deg,#F4FFF8,#F8FFFB);
# border:1px solid #D9F3E4;
# box-shadow:0 8px 20px rgba(16,185,129,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.6px;
# color:#059669;
# margin-bottom:7px;
# ">
# 3.3 · COMMON STREAMLIT WIDGETS
# </div>
#
# <div style="
# font-size:23px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:10px;
# ">
# Choosing the Right
# <span style="color:#10B981;">Input Widget</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.75;
# color:#4B5563;
# margin-bottom:12px;
# ">
# The best widget depends on the type of data the model expects.
# Streamlit provides different components for
# <span style="color:#059669;font-weight:800;">numbers</span>,
# <span style="color:#2563EB;font-weight:800;">categories</span>,
# <span style="color:#EC4899;font-weight:800;">text</span>,
# and uploaded files.
# </div>
#
# <div style="
# display:grid;
# grid-template-columns:1fr 1fr;
# gap:10px;
# font-size:13.5px;
# ">
#
# <div style="padding:11px 13px;border-radius:12px;background:#FFFFFF;border:1px solid #E5F3EA;">
# <span style="color:#059669;font-weight:800;">st.number_input / st.slider</span><br>
# <span style="color:#64748B;">Numeric values</span>
# </div>
#
# <div style="padding:11px 13px;border-radius:12px;background:#FFFFFF;border:1px solid #E5F3EA;">
# <span style="color:#2563EB;font-weight:800;">st.selectbox / st.radio</span><br>
# <span style="color:#64748B;">Category selection</span>
# </div>
#
# <div style="padding:11px 13px;border-radius:12px;background:#FFFFFF;border:1px solid #E5F3EA;">
# <span style="color:#EC4899;font-weight:800;">st.text_input / st.text_area</span><br>
# <span style="color:#64748B;">Text input</span>
# </div>
#
# <div style="padding:11px 13px;border-radius:12px;background:#FFFFFF;border:1px solid #E5F3EA;">
# <span style="color:#D97706;font-weight:800;">st.file_uploader</span><br>
# <span style="color:#64748B;">Images or files</span>
# </div>
#
# </div>
#
# <div style="
# margin-top:12px;
# font-size:13.5px;
# line-height:1.7;
# color:#475569;
# ">
# For the IMDb sentiment project,
# <span style="color:#EC4899;font-weight:800;">st.text_area()</span>
# is the most suitable choice because the user enters a complete movie review.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:22px 24px;
# border-radius:18px;
# background:linear-gradient(135deg,#FFF9F3,#FFFCF7);
# border:1px solid #F6E2C8;
# box-shadow:0 8px 20px rgba(245,158,11,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:16px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.6px;
# color:#D97706;
# margin-bottom:7px;
# ">
# 3.4 · DESIGNING A USABLE DEMO
# </div>
#
# <div style="
# font-size:23px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:10px;
# ">
# Simple, Clear, and
# <span style="color:#F59E0B;">Presentation-Ready</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.75;
# color:#4B5563;
# margin-bottom:12px;
# ">
# A good Streamlit demo should let a first-time user understand what to do within a few seconds.
# The interface should include a
# <span style="color:#7C3AED;font-weight:800;">clear title</span>,
# a short description,
# a suitable input field,
# and a visible prediction result.
# </div>
#
# <div style="
# padding:12px 14px;
# border-radius:13px;
# background:#FFFFFF;
# border:1px solid #F3E6D5;
# font-size:13.5px;
# line-height:1.7;
# color:#475569;
# margin-bottom:10px;
# ">
# For this IMDb project, the dashboard shows the
# <span style="color:#EC4899;font-weight:800;">movie review input</span>,
# the predicted
# <span style="color:#16A34A;font-weight:800;">sentiment</span>,
# and
# <span style="color:#D97706;font-weight:800;">confidence probabilities</span>
# so the result is easy to interpret.
# </div>
#
# <div style="
# font-size:13.5px;
# line-height:1.7;
# color:#475569;
# ">
# The app should also handle
# <span style="color:#DC2626;font-weight:800;">empty or invalid input</span>
# cleanly instead of crashing.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:24px 26px;
# border-radius:20px;
# background:linear-gradient(135deg,#F5F3FF,#F8FAFF,#FFF7FB);
# border:1px solid #E6E2F2;
# box-shadow:0 8px 22px rgba(79,70,229,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.8px;
# color:#7C3AED;
# margin-bottom:7px;
# ">
# HANDS-ON LAB
# </div>
#
# <div style="
# font-size:25px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:9px;
# ">
# Building the
# <span style="color:#EC4899;">IMDb Streamlit Demo</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.75;
# color:#4B5563;
# ">
# Now the saved
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>
# and
# <span style="color:#2563EB;font-weight:800;">TF-IDF vectorizer</span>
# will be connected to an interactive Streamlit interface and tested locally.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:19px 22px;
# border-radius:17px;
# background:linear-gradient(135deg,#F4F8FF,#FAFCFF);
# border-left:5px solid #3B82F6;
# font-family:'Trebuchet MS',sans-serif;
# margin:15px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.4px;
# color:#2563EB;
# margin-bottom:5px;
# ">
# STEP 01
# </div>
#
# <div style="
# font-size:21px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:7px;
# ">
# Locate the Saved
# <span style="color:#3B82F6;">Deployment Artifacts</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#4B5563;
# ">
# Before building the dashboard, verify that
# <span style="color:#7C3AED;font-weight:800;">model.joblib</span>
# and
# <span style="color:#2563EB;font-weight:800;">vectorizer.joblib</span>
# are available from Day 1.
# </div>
#
# </div>

# %%
import joblib
from pathlib import Path

CURRENT_DIR = Path.cwd()

MODEL_PATH = CURRENT_DIR.parent / "Day1" / "model.joblib"
VECTORIZER_PATH = CURRENT_DIR.parent / "Day1" / "vectorizer.joblib"

print("Model path:", MODEL_PATH)
print("Model exists:", MODEL_PATH.exists())

print("\nVectorizer path:", VECTORIZER_PATH)
print("Vectorizer exists:", VECTORIZER_PATH.exists())
# Out:
# Model path: d:\Main_Folder_main\Week9\Day1\model.joblib
# Model exists: True
#
# Vectorizer path: d:\Main_Folder_main\Week9\Day1\vectorizer.joblib
# Vectorizer exists: True

# %% [markdown]
# <div style="
# padding:15px 18px;
# border-radius:15px;
# background:#F0FDF4;
# border:1px solid #BBF7D0;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# ">
#
# <span style="color:#16A34A;font-weight:900;">✓ Artifact Check:</span>
# <span style="color:#475569;font-size:13.8px;">
# Both the saved model and TF-IDF vectorizer were found successfully, so the Streamlit application can reuse the original training pipeline without retraining.
# </span>
#
# </div>

# %% [markdown]
# <div style="
# padding:19px 22px;
# border-radius:17px;
# background:linear-gradient(135deg,#F8F7FF,#FCFBFF);
# border-left:5px solid #8B5CF6;
# font-family:'Trebuchet MS',sans-serif;
# margin:15px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.4px;
# color:#7C3AED;
# margin-bottom:5px;
# ">
# STEP 02
# </div>
#
# <div style="
# font-size:21px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:7px;
# ">
# Load the Saved
# <span style="color:#8B5CF6;">Model & Vectorizer</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#4B5563;
# ">
# The application loads the trained artifacts directly from disk so the same
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>
# and
# <span style="color:#2563EB;font-weight:800;">TF-IDF feature space</span>
# are reused during deployment.
# </div>
#
# </div>

# %%
model = joblib.load(MODEL_PATH)
vectorizer = joblib.load(VECTORIZER_PATH)

print("Model loaded successfully:", type(model).__name__)
print("Vectorizer loaded successfully:", type(vectorizer).__name__)
# Out:
# Model loaded successfully: LogisticRegression
# Vectorizer loaded successfully: TfidfVectorizer

# %% [markdown]
# <div style="
# padding:14px 18px;
# border-radius:14px;
# background:#F0FDF4;
# border:1px solid #BBF7D0;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# font-size:13.8px;
# line-height:1.7;
# color:#475569;
# ">
#
# <span style="color:#16A34A;font-weight:900;">✓ Loaded Successfully:</span>
# The trained classifier and TF-IDF vectorizer are now ready for prediction inside the Streamlit application.
#
# </div>

# %% [markdown]
# <div style="
# padding:19px 22px;
# border-radius:17px;
# background:linear-gradient(135deg,#FFF8FB,#FCFAFF);
# border-left:5px solid #EC4899;
# font-family:'Trebuchet MS',sans-serif;
# margin:15px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.4px;
# color:#DB2777;
# margin-bottom:5px;
# ">
# STEP 03
# </div>
#
# <div style="
# font-size:21px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:7px;
# ">
# Test the
# <span style="color:#EC4899;">Prediction Pipeline</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#4B5563;
# ">
# Before connecting the model to Streamlit, test the full prediction flow directly in the notebook:
# <span style="color:#7C3AED;font-weight:800;">review → TF-IDF → model → sentiment</span>.
# </div>
#
# </div>

# %%
sample_review = "The movie was fantastic, emotional, and beautifully acted."

review_vector = vectorizer.transform([sample_review])

prediction = model.predict(review_vector)[0]
probabilities = model.predict_proba(review_vector)[0]

classes = list(model.classes_)

negative_prob = probabilities[classes.index(0)]
positive_prob = probabilities[classes.index(1)]

sentiment = "Positive" if prediction == 1 else "Negative"

print("Review:", sample_review)
print("Prediction:", sentiment)
print(f"Positive Probability: {positive_prob * 100:.2f}%")
print(f"Negative Probability: {negative_prob * 100:.2f}%")
# Out:
# Review: The movie was fantastic, emotional, and beautifully acted.
# Prediction: Positive
# Positive Probability: 97.56%
# Negative Probability: 2.44%

# %% [markdown]
# <div style="
# padding:14px 18px;
# border-radius:14px;
# background:#F0FDF4;
# border:1px solid #BBF7D0;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# font-size:13.8px;
# line-height:1.7;
# color:#475569;
# ">
#
# <span style="color:#16A34A;font-weight:900;">✓ Pipeline Verified:</span>
# The complete prediction pipeline works correctly before being connected to the Streamlit interface.
#
# </div>

# %% [markdown]
# <div style="
# padding:19px 22px;
# border-radius:17px;
# background:linear-gradient(135deg,#F7F5FF,#FBFAFF);
# border-left:5px solid #8B5CF6;
# font-family:'Trebuchet MS',sans-serif;
# margin:15px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.4px;
# color:#7C3AED;
# margin-bottom:5px;
# ">
# STEP 04
# </div>
#
# <div style="
# font-size:21px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:7px;
# ">
# Build the
# <span style="color:#8B5CF6;">Streamlit Interface</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#4B5563;
# ">
# The dashboard is implemented in
# <span style="color:#7C3AED;font-weight:800;">app.py</span>.
# It loads the saved artifacts, accepts a movie review, performs the prediction, and displays the sentiment with confidence probabilities.
# </div>
#
# </div>

# %%
app_code = '''
import streamlit as st
import joblib
from pathlib import Path

st.set_page_config(
    page_title="IMDb Sentiment Analyzer",
    page_icon="🎬",
    layout="centered"
)

CURRENT_DIR = Path(__file__).resolve().parent
MODEL_PATH = CURRENT_DIR.parent / "Day1" / "model.joblib"
VECTORIZER_PATH = CURRENT_DIR.parent / "Day1" / "vectorizer.joblib"

@st.cache_resource
def load_artifacts():
    model = joblib.load(MODEL_PATH)
    vectorizer = joblib.load(VECTORIZER_PATH)
    return model, vectorizer

model, vectorizer = load_artifacts()

st.title("🎬 IMDb Sentiment Analyzer")
st.write(
    "Enter a movie review and let the model predict "
    "whether the sentiment is Positive or Negative."
)

review = st.text_area(
    "Movie Review",
    height=180,
    placeholder="Example: This movie was amazing and beautifully acted..."
)

if st.button("Analyze Sentiment", use_container_width=True):

    if review.strip() == "":
        st.warning("Please enter a movie review first.")

    else:
        review_vector = vectorizer.transform([review])
        prediction = model.predict(review_vector)[0]

        probabilities = model.predict_proba(review_vector)[0]
        confidence = max(probabilities)

        if prediction == 1:
            st.success("😊 Positive Sentiment")
        else:
            st.error("😕 Negative Sentiment")

        st.write(f"Confidence: {confidence * 100:.2f}%")

        classes = list(model.classes_)

        negative_prob = probabilities[classes.index(0)]
        positive_prob = probabilities[classes.index(1)]

        st.subheader("Prediction Probabilities")

        st.write(f"Positive: {positive_prob * 100:.2f}%")
        st.progress(float(positive_prob))

        st.write(f"Negative: {negative_prob * 100:.2f}%")
        st.progress(float(negative_prob))

st.divider()
st.caption("IMDb Sentiment Analysis • TF-IDF + Logistic Regression")
'''

print(app_code)
# Out:
# import streamlit as st
# import joblib
# from pathlib import Path
#
# st.set_page_config(
#     page_title="IMDb Sentiment Analyzer",
#     page_icon="🎬",
#     layout="centered"
# )
#
# CURRENT_DIR = Path(__file__).resolve().parent
# MODEL_PATH = CURRENT_DIR.parent / "Day1" / "model.joblib"
# VECTORIZER_PATH = CURRENT_DIR.parent / "Day1" / "vectorizer.joblib"
#
# @st.cache_resource
# def load_artifacts():
#     model = joblib.load(MODEL_PATH)
#     vectorizer = joblib.load(VECTORIZER_PATH)
#     return model, vectorizer
#
# model, vectorizer = load_artifacts()
#
# st.title("🎬 IMDb Sentiment Analyzer")
# st.write(
#     "Enter a movie review and let the model predict "
#     "whether the sentiment is Positive or Negative."
# )
#
# review = st.text_area(
#     "Movie Review",
#     height=180,
#     placeholder="Example: This movie was amazing and beautifully acted..."
# )
#
# if st.button("Analyze Sentiment", use_container_width=True):
#
#     if review.strip() == "":
# ...

# %% [markdown]
# <div style="
# padding:14px 18px;
# border-radius:14px;
# background:#F5F3FF;
# border:1px solid #DDD6FE;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# font-size:13.8px;
# line-height:1.7;
# color:#475569;
# ">
#
# <span style="color:#7C3AED;font-weight:900;">App Structure:</span>
# The Streamlit script combines model loading, review input, prediction, confidence scoring, and probability visualization inside one simple user-facing interface.
#
# </div>

# %% [markdown]
# <div style="
# padding:19px 22px;
# border-radius:17px;
# background:linear-gradient(135deg,#FFF9F3,#FFFCF8);
# border-left:5px solid #F59E0B;
# font-family:'Trebuchet MS',sans-serif;
# margin:15px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.4px;
# color:#D97706;
# margin-bottom:5px;
# ">
# STEP 05
# </div>
#
# <div style="
# font-size:21px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:7px;
# ">
# Run and Test the
# <span style="color:#F59E0B;">Streamlit App</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#4B5563;
# ">
# The application is launched locally using the Streamlit command.
# Testing confirms that the complete flow works from
# <span style="color:#7C3AED;font-weight:800;">user input</span>
# to
# <span style="color:#16A34A;font-weight:800;">sentiment prediction</span>
# and probability display.
# </div>
#
# </div>

# %%
print("Run the application from the Day3 folder using:")
print()
print("streamlit run app.py")
# Out:
# Run the application from the Day3 folder using:
#
# streamlit run app.py

# %% [markdown]
# <div style="
# padding:14px 18px;
# border-radius:14px;
# background:#FFFBEB;
# border:1px solid #FDE68A;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# font-size:13.8px;
# line-height:1.7;
# color:#475569;
# ">
#
# <span style="color:#D97706;font-weight:900;">✓ Local Test:</span>
# The Streamlit application launched successfully in the browser and accepted movie reviews without requiring API requests or JSON input.
#
# </div>

# %% [markdown]
# <div style="
# padding:19px 22px;
# border-radius:17px;
# background:linear-gradient(135deg,#F4FFF8,#FBFFFD);
# border-left:5px solid #22C55E;
# font-family:'Trebuchet MS',sans-serif;
# margin:15px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.4px;
# color:#16A34A;
# margin-bottom:5px;
# ">
# STEP 06
# </div>
#
# <div style="
# font-size:21px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:7px;
# ">
# Document the
# <span style="color:#22C55E;">Prediction Results</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#4B5563;
# ">
# The final Streamlit dashboard was tested using both
# <span style="color:#16A34A;font-weight:800;">positive</span>
# and
# <span style="color:#DC2626;font-weight:800;">negative</span>
# movie reviews to verify the complete user flow and confidence visualization.
# </div>
#
# </div>

# %% [markdown]
# ![Screenshot 2026-09-15 003154.png](<attachment:Screenshot 2026-09-15 003154.png>)

# %% [markdown]
# ![Screenshot 2026-09-15 003830.png](<attachment:Screenshot 2026-09-15 003830.png>)

# %% [markdown]
# <div style="
# padding:15px 18px;
# border-radius:15px;
# background:linear-gradient(135deg,#F0FDF4,#F7FFF9);
# border:1px solid #BBF7D0;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.3px;
# color:#16A34A;
# margin-bottom:5px;
# ">
# POSITIVE TEST RESULT
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# The review was classified as
# <span style="color:#16A34A;font-weight:900;">Positive</span>
# with
# <span style="color:#7C3AED;font-weight:900;">97.56% confidence</span>.
#
# The probability distribution strongly supports the prediction:
# <span style="color:#16A34A;font-weight:800;">97.56% Positive</span>
# versus
# <span style="color:#DC2626;font-weight:800;">2.44% Negative</span>.
# </div>
#
# </div>

# %% [markdown]
# ![Screenshot 2026-09-15 003917.png](<attachment:Screenshot 2026-09-15 003917.png>)

# %% [markdown]
# <div style="
# padding:15px 18px;
# border-radius:15px;
# background:linear-gradient(135deg,#FFF7F7,#FFFAFA);
# border:1px solid #FECACA;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.3px;
# color:#DC2626;
# margin-bottom:5px;
# ">
# NEGATIVE TEST RESULT
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#475569;
# ">
# The review was classified as
# <span style="color:#DC2626;font-weight:900;">Negative</span>
# with
# <span style="color:#7C3AED;font-weight:900;">99.96% confidence</span>.
#
# The model assigned only
# <span style="color:#16A34A;font-weight:800;">0.04% Positive</span>
# and
# <span style="color:#DC2626;font-weight:800;">99.96% Negative</span>,
# showing very strong confidence in the negative prediction.
# </div>
#
# </div>

# %% [markdown]
# <div style="
# padding:19px 22px;
# border-radius:17px;
# background:linear-gradient(135deg,#FFF8F8,#FFFDFB);
# border-left:5px solid #EF4444;
# font-family:'Trebuchet MS',sans-serif;
# margin:15px 0 10px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.4px;
# color:#DC2626;
# margin-bottom:5px;
# ">
# EDGE-CASE TESTING
# </div>
#
# <div style="
# font-size:21px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:7px;
# ">
# Testing Unusual
# <span style="color:#EF4444;">User Inputs</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.7;
# color:#4B5563;
# ">
# A reliable demo should handle more than clear positive and negative reviews.
# The application is also checked using
# <span style="color:#DC2626;font-weight:800;">empty input</span>
# and a
# <span style="color:#7C3AED;font-weight:800;">short or ambiguous review</span>
# to evaluate its behavior in less ideal situations.
# </div>
#
# </div>

# %%
ambiguous_review = "It was okay."

review_vector = vectorizer.transform([ambiguous_review])

prediction = model.predict(review_vector)[0]
probabilities = model.predict_proba(review_vector)[0]

classes = list(model.classes_)

negative_prob = probabilities[classes.index(0)]
positive_prob = probabilities[classes.index(1)]

sentiment = "Positive" if prediction == 1 else "Negative"
confidence = max(probabilities)

print("Review:", ambiguous_review)
print("Prediction:", sentiment)
print(f"Confidence: {confidence * 100:.2f}%")
print(f"Positive Probability: {positive_prob * 100:.2f}%")
print(f"Negative Probability: {negative_prob * 100:.2f}%")
# Out:
# Review: It was okay.
# Prediction: Negative
# Confidence: 89.92%
# Positive Probability: 10.08%
# Negative Probability: 89.92%

# %%
empty_review = ""

if empty_review.strip() == "":
    print("Warning: Please enter a movie review first.")

# %% [markdown]
# <div style="
# padding:15px 18px;
# border-radius:15px;
# background:#FFF7ED;
# border:1px solid #FED7AA;
# font-family:'Trebuchet MS',sans-serif;
# margin:10px 0 18px 0;
# font-size:13.8px;
# line-height:1.7;
# color:#475569;
# ">
#
# <span style="color:#EA580C;font-weight:900;">Edge-Case Observation:</span>
# Empty input is blocked before prediction and produces a warning instead of an error.
#
# A very short or ambiguous review can still be classified, but its confidence should be interpreted carefully because the model receives much less sentiment information than in a detailed review.
#
# </div>

# %% [markdown]
# <div style="
# padding:24px 26px;
# border-radius:20px;
# background:linear-gradient(135deg,#F7FAFF,#F5F3FF,#F4FFF8);
# border:1px solid #E3E7EF;
# box-shadow:0 9px 24px rgba(79,70,229,.06);
# font-family:'Trebuchet MS',sans-serif;
# margin:18px 0 8px 0;
# ">
#
# <div style="
# font-size:11px;
# font-weight:800;
# letter-spacing:1.7px;
# color:#7C3AED;
# margin-bottom:7px;
# ">
# DAY 3 · FINAL CONCLUSION
# </div>
#
# <div style="
# font-size:24px;
# font-weight:900;
# color:#1F2937;
# margin-bottom:11px;
# ">
# From Trained Model to
# <span style="color:#16A34A;">Interactive Application</span>
# </div>
#
# <div style="
# font-size:14px;
# line-height:1.75;
# color:#4B5563;
# ">
# In Day 3, the saved IMDb sentiment model was successfully transformed into an
# <span style="color:#EC4899;font-weight:800;">interactive Streamlit dashboard</span>.
#
# The application reuses the original
# <span style="color:#2563EB;font-weight:800;">TF-IDF vectorizer</span>
# and
# <span style="color:#7C3AED;font-weight:800;">Logistic Regression model</span>,
# accepts movie reviews through a user-friendly interface, and returns a clear sentiment prediction with confidence probabilities.
#
# The final local tests confirmed that the complete deployment flow works correctly for both
# <span style="color:#16A34A;font-weight:800;">positive</span>
# and
# <span style="color:#DC2626;font-weight:800;">negative</span>
# reviews.
# </div>
#
# <div style="
# margin-top:13px;
# padding:12px 14px;
# border-radius:13px;
# background:#FFFFFF;
# border:1px solid #E5E7EB;
# font-size:13.5px;
# color:#475569;
# ">
# <span style="color:#7C3AED;font-weight:900;">Final Flow:</span>
# Review → TF-IDF → Logistic Regression → Sentiment → Confidence → Streamlit UI
# </div>
#
# </div>
