# %% [markdown]
# <div style="padding:24px 26px;border-radius:14px;background:linear-gradient(135deg,#8f6f83,#c98fa8);margin-bottom:20px;box-shadow:0 6px 18px rgba(120,90,110,0.12);">
# <h1 style="margin:0;color:white;font-size:34px;">Cardiac Patient Monitoring System</h1>
# <p style="margin:8px 0 0 0;color:#fff7fb;font-size:18px;">Milestone 1 — Understanding the Data</p>
# <p style="margin:6px 0 0 0;color:#f7eaf0;font-size:14px;">Heart Disease Cleveland Dataset · Data Understanding & Quality Check</p>
# </div>

# %% [markdown]
# <div style="background:#ffffff;border:1px solid #eee6eb;border-radius:12px;padding:18px 20px;margin:12px 0 18px 0;">
# <h2 style="color:#b57491;margin-top:0;">Introduction</h2>
# <p style="color:#4a4a4a;">This project starts with the <b>Heart Disease Cleveland dataset</b>, which contains clinical information for patients that may be related to heart disease.</p>
# <p style="color:#4a4a4a;">Before moving into modeling, I first want to understand the patients represented in the dataset and check whether the available information is reliable enough for later analysis.</p>
# <p style="color:#4a4a4a;">The dataset contains <b>303 patient records</b>, described by <b>13 input features</b>, while the <code>target</code> column represents the outcome that will later be predicted.</p>
# <div style="background:#fff7fa;border-left:4px solid #c98fa8;border-radius:8px;padding:13px 15px;margin-top:14px;">
# <p style="color:#b57491;font-weight:bold;margin-top:0;">Main Question</p>
# <p style="color:#4a4a4a;margin-bottom:0;">Is the data itself ready to be trusted before machine learning begins?</p>
# </div>
# </div>

# %% [markdown]
# <div style="background:#f8f3f6;border:1px solid #eadfe5;border-radius:12px;padding:16px 18px;margin:12px 0 20px 0;">
# <p style="color:#8f6f83;font-weight:bold;font-size:18px;margin-top:0;">Milestone 1 Roadmap</p>
# <div style="display:flex;flex-wrap:wrap;align-items:center;gap:8px;color:#4a4a4a;">
# <span style="background:white;padding:8px 12px;border-radius:8px;">Load Data</span>
# <span style="color:#c98fa8;font-weight:bold;">→</span>
# <span style="background:white;padding:8px 12px;border-radius:8px;">Inspect Structure</span>
# <span style="color:#c98fa8;font-weight:bold;">→</span>
# <span style="background:white;padding:8px 12px;border-radius:8px;">Check Quality</span>
# <span style="color:#c98fa8;font-weight:bold;">→</span>
# <span style="background:white;padding:8px 12px;border-radius:8px;">Validate Values</span>
# <span style="color:#c98fa8;font-weight:bold;">→</span>
# <span style="background:#efe4ea;padding:8px 12px;border-radius:8px;color:#8f6f83;font-weight:bold;">Save Checked Data</span>
# </div>
# </div>

# %% [markdown]
# <h2 style="color:#8f6f83;font-weight:bold;">Environment</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">This project is developed in Jupyter Notebook using Python with Pandas, NumPy, Matplotlib, and Scikit-learn.</p></div>

# %%
import sys
import pandas as pd
import numpy as np

print("Python version:", sys.version.split()[0])
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)

# %% [markdown]
# <h2 style="color:#8f6f83;font-weight:bold;">Dataset Source</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#4a4a4a;margin:0;">The dataset used in this project is the <b>Heart Disease Cleveland dataset</b>, downloaded from Kaggle for educational machine-learning analysis.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">1. Loading the Dataset</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">Before changing or cleaning anything, I want to see the data exactly as it was provided.</p></div>

# %%
# Load the Cleveland Heart Disease dataset
df = pd.read_csv("../data/Heart_disease_cleveland_new.csv")

# Display the first five patient records
df.head()

# %% [markdown]
# <div style="background:#f3eef5;border:1px solid #e4dbe8;border-radius:9px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#8f748f;font-weight:bold;margin-top:0;">Observation</p><p style="color:#4a4a4a;margin-bottom:0;">The first rows show that the dataset contains both numerical measurements and features represented using numeric codes. The <code>target</code> column is also included and will later be used as the outcome for the classification task.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">2. How Large Is the Dataset?</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">Knowing the number of patient records and columns gives a clearer picture of the amount of data available for the analysis.</p></div>

# %%
# Check the number of rows and columns
df.shape

# %% [markdown]
# <div style="background:#f3eef5;border:1px solid #e4dbe8;border-radius:9px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#8f748f;font-weight:bold;margin-top:0;">Observation</p><p style="color:#4a4a4a;margin-bottom:0;">The dataset contains <b>303 patient records and 14 columns</b>. Among these columns, <b>13 are input features</b> and <code>target</code> is the outcome for classification.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">3. What Information Does Each Patient Record Contain?</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">Next, I will inspect the available columns to understand what type of information is stored for each patient.</p></div>

# %%
# Display all column names
df.columns.tolist()

# %% [markdown]
# <div style="background:#f3eef5;border:1px solid #e4dbe8;border-radius:9px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#8f748f;font-weight:bold;margin-top:0;">Observation</p><p style="color:#4a4a4a;margin-bottom:0;">The dataset contains 13 patient features and one target column. Some columns contain direct numerical measurements, while others use numbers to represent categories.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">4. Data Dictionary</h2>
#
# | Feature | Description |
# |---|---|
# | `age` | Age of the patient in years |
# | `sex` | Sex of the patient: 0 = female, 1 = male |
# | `cp` | Chest pain type: 0 = typical angina, 1 = atypical angina, 2 = non-anginal pain, 3 = asymptomatic |
# | `trestbps` | Resting blood pressure in mm Hg |
# | `chol` | Serum cholesterol in mg/dl |
# | `fbs` | Fasting blood sugar > 120 mg/dl: 0 = false, 1 = true |
# | `restecg` | Resting ECG result: 0 = normal, 1 = ST-T abnormality, 2 = left ventricular hypertrophy |
# | `thalach` | Maximum heart rate achieved |
# | `exang` | Exercise-induced angina: 0 = no, 1 = yes |
# | `oldpeak` | ST depression induced by exercise relative to rest |
# | `slope` | Slope of the peak exercise ST segment: 0 = upsloping, 1 = flat, 2 = downsloping |
# | `ca` | Number of major vessels |
# | `thal` | Thal result: 1 = normal, 2 = fixed defect, 3 = reversible defect |
# | `target` | Heart disease status: 0 = absence, 1 = presence |

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">5. Checking the Dataset Structure</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">Before cleaning the data, I want to inspect the data types and make sure each column contains the expected number of values.</p></div>

# %%
df.info()

# %% [markdown]
# <div style="background:#f3eef5;border:1px solid #e4dbe8;border-radius:9px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#8f748f;font-weight:bold;margin-top:0;">Observation</p><p style="color:#4a4a4a;margin-bottom:0;">All 14 columns contain 303 non-null values. Most columns are stored as integers, while <code>oldpeak</code> is stored as a float because it contains decimal values.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">6. Are There Any Missing Values?</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">Missing values can affect both analysis and model training, so I need to confirm whether any patient record is incomplete.</p></div>

# %%
df.isnull().sum()

# %% [markdown]
# <div style="background:#f3eef5;border:1px solid #e4dbe8;border-radius:9px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#8f748f;font-weight:bold;margin-top:0;">Observation</p><p style="color:#4a4a4a;margin-bottom:0;">All columns have <b>0 missing values</b>, so the dataset is complete according to this check.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">7. Are There Any Duplicate Records?</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">Even if the dataset is complete, repeated patient records could still affect the analysis, so I will check for duplicate rows.</p></div>

# %%
df.duplicated().sum()

# %% [markdown]
# <div style="background:#f3eef5;border:1px solid #e4dbe8;border-radius:9px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#8f748f;font-weight:bold;margin-top:0;">Observation</p><p style="color:#4a4a4a;margin-bottom:0;">No duplicate rows were found, so no records need to be removed for duplication.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">8. Are the Values Reasonable?</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">I will inspect the unique values of the coded categorical features to make sure they match the expected categories.</p></div>

# %%
categorical_col = [
    "sex", "cp", "fbs", "restecg",
    "exang", "slope", "ca", "thal", "target"
]

for column in categorical_col:
    print(f"{column}: {sorted(df[column].unique())}")

# %% [markdown]
# <div style="background:#f3eef5;border:1px solid #e4dbe8;border-radius:9px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#8f748f;font-weight:bold;margin-top:0;">Observation</p><p style="color:#4a4a4a;margin-bottom:0;">The coded features contain the expected category values. Binary features such as <code>sex</code>, <code>fbs</code>, <code>exang</code>, and <code>target</code> contain only 0 and 1.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">9. Checking Numerical Ranges</h2><div style="background:#ffffff;border:1px solid #eee6eb;border-radius:10px;padding:14px 16px;margin:10px 0 14px 0;"><p style="color:#4a4a4a;margin:0;">Next, I will inspect the numerical measurements and check whether their ranges look reasonable.</p></div>

# %%
df[["age", "trestbps", "chol", "thalach", "oldpeak"]].describe()

# %% [markdown]
# <div style="background:#f3eef5;border:1px solid #e4dbe8;border-radius:9px;padding:14px 16px;margin:10px 0 18px 0;"><p style="color:#8f748f;font-weight:bold;margin-top:0;">Observation</p><p style="color:#4a4a4a;">Patient ages range from <b>29 to 77 years</b>, resting blood pressure from <b>94 to 200 mm Hg</b>, cholesterol from <b>126 to 564 mg/dl</b>, and maximum heart rate from <b>71 to 202 bpm</b>.</p><p style="color:#4a4a4a;margin-bottom:0;">Some high values stand out, but I will keep them for now and examine them during EDA instead of removing them without evidence.</p></div>

# %% [markdown]
# <h2 style="color:#c07b98;font-weight:bold;">10. Initial Cleaning Decision</h2>
# <div style="background:#f8f3f6;border:1px solid #eadfe5;border-radius:10px;padding:14px 16px;margin:10px 0 16px 0;">
# <p style="color:#8f6f83;font-weight:bold;margin-top:0;">Cleaning Summary</p>
# <ul style="color:#4a4a4a;margin-bottom:0;">
# <li>No missing values were found.</li>
# <li>No duplicate rows were found.</li>
# <li>The categorical codes matched the expected values.</li>
# <li>The numerical values looked reasonable overall.</li>
# <li>Some high values were kept for later EDA instead of being removed without evidence.</li>
# </ul>
# </div>

# %%
df.to_csv("../data/heart_cleveland_checked.csv", index=False)

# %% [markdown]
# <h2 style="color:#b57491;font-weight:bold;">Milestone 1 Takeaway</h2>
# <div style="background:linear-gradient(135deg,#fff9fb,#f3edf2);border:1px solid #e8dce3;border-radius:12px;padding:16px 18px;margin:10px 0 18px 0;">
# <ul style="color:#4a4a4a;margin-bottom:0;">
# <li>The dataset contains <b>303 patient records</b>, <b>13 input features</b>, and one target column.</li>
# <li>No missing values or duplicate records were found.</li>
# <li>The coded categorical values matched the expected categories.</li>
# <li>The numerical ranges looked reasonable overall, so no records were removed at this stage.</li>
# <li>The checked dataset was saved and is ready for the next milestone: exploratory data analysis.</li>
# </ul>
# </div>
