# %% [markdown]
#  Check Installed Versions
#
# ##The following code prints the versions of Python, NumPy, Pandas, and Matplotlib.

# %%
import pandas as pd 
import numpy as np
import matplotlib

# %%
print(np.__version__)
print(pd.__version__)
print(matplotlib.__version__)
# Out:
# 2.5.1
# 3.0.3
# 3.11.0

# %% [markdown]
# result
